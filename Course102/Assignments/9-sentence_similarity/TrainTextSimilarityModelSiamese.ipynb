# %% [markdown]
# # 基于Bert训练一个文本相似度模型
#
# bert+maxpooling +cosine 计算相似度，只使用正例进行训练（约占训练集1/3 1w条数据）

# %%
from transformers import AutoTokenizer,TFAutoModel,AutoConfig,TFAutoModelForSequenceClassification
import tensorflow as tf
from tensorflow import keras 
import json
from collections import defaultdict
import numpy as np
gpus = tf.config.list_physical_devices('GPU')
if len(gpus)>1:
    tf.config.set_visible_devices(gpus[1], 'GPU')
    print('use gpu1')
# Out:
# use gpu1

# %%
# config = AutoConfig.from_pretrained('bert-base-chinese')
tokenizer = AutoTokenizer.from_pretrained('bert-base-chinese')
model = TFAutoModel.from_pretrained('bert-base-chinese')
# Out:
# 2022-03-14 17:55:12.277740: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-14 17:55:12.836827: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6390 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080, pci bus id: 0000:b3:00.0, compute capability: 7.5
# Some layers from the model checkpoint at bert-base-chinese were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-chinese.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %% [markdown]
# ## 构造数据集
#
# ### 这里使用 AFQMC 蚂蚁金融语义相似度 Ant Financial Question Matching Corpus， 但只使用其中的正例模拟常见应用场景

# %%
sentence_pairs=[]
with open('train.json') as f:
    for l in f.readlines():
        data = json.loads(l)
        if data['label'] == '1':
            sentence_pairs.append((data['sentence1'],data['sentence2']))

# %%
print('训练数据对数：',len(sentence_pairs))
print('训练数据平均长度：', sum([len(s1)+len(s2) for s1,s2 in sentence_pairs])/(len(sentence_pairs)*2))
print('训练数据最大长度：', max([max(len(s1),len(s2)) for s1,s2 in sentence_pairs]))
# Out:
# 训练数据对数： 10573
# 训练数据平均长度： 13.40915539581954
# 训练数据最大长度： 90

# %%
MAX_LEN = 50

# %%
s0_encoded = tokenizer([p[0] for p in sentence_pairs], padding=True, truncation=True, max_length=MAX_LEN,return_tensors="tf")
s1_encoded = tokenizer([p[1] for p in sentence_pairs], padding=True, truncation=True, max_length=MAX_LEN,return_tensors="tf")

# %%
# 读取dev数据
dev_sentence_pairs=[]
dev_labels=[]
with open('dev.json') as f:
    for l in f.readlines():
        data = json.loads(l)
        dev_sentence_pairs.append((data['sentence1'],data['sentence2']))
        dev_labels.append(True if data['label']=='1' else False)
dev_s0_encoded = tokenizer([p[0] for p in dev_sentence_pairs], padding=True, truncation=True, max_length=MAX_LEN,return_tensors="tf")
dev_s1_encoded = tokenizer([p[1] for p in dev_sentence_pairs], padding=True, truncation=True, max_length=MAX_LEN,return_tensors="tf")
dev_s1_input_ids = dev_s0_encoded['input_ids']
dev_s1_token_type_ids = dev_s0_encoded['token_type_ids']
dev_s1_attention_mask = dev_s0_encoded['attention_mask']
dev_s2_input_ids = dev_s1_encoded['input_ids']
dev_s2_token_type_ids = dev_s1_encoded['token_type_ids']
dev_s2_attention_mask = dev_s1_encoded['attention_mask']
dev_labels = tf.constant(dev_labels)

# %% [markdown]
# ## 构建模型

# %%
# model.trainable = False

@tf.function
def max_pooling_with_mask(paras):
    sent_word_embeddings,sent_indices = paras
    not_padding = tf.math.not_equal(sent_indices,0)
    not_cls = tf.math.not_equal(sent_indices,101) # cls
    not_seg = tf.math.not_equal(sent_indices,102) # sep
    mask = tf.math.logical_and(not_padding,not_cls)
    mask = tf.math.logical_and(mask,not_seg)
    mask_f = tf.cast(mask,tf.float32)
    mask_f = tf.expand_dims(mask_f,axis=-1)
    return tf.reduce_mean(tf.multiply(sent_word_embeddings,mask_f),axis=1)

def convert_bert_to_sentence_embedding_model(bert_model,sentence_embedding_size=256):
    input_ids = keras.Input(shape=(None,),dtype=tf.int32)
    token_type_ids = keras.Input(shape=(None,),dtype=tf.int32)
    attention_mask = keras.Input(shape=(None,),dtype=tf.int32)
    output = bert_model(input_ids,token_type_ids,attention_mask)
    bert_embeddings = output.last_hidden_state
    sentence_embeddings = keras.layers.Lambda(max_pooling_with_mask,name='lambda_max_pooling')([bert_embeddings,input_ids]) # 这里使用max_pooling作为句子的embedding
    # sentence_embeddings = keras.layers.Dense(sentence_embedding_size,name='dense_layer',activation='relu')(sentence_embeddings)
    normalized_sentence_embeddings = keras.layers.Lambda(lambda xt: tf.nn.l2_normalize(xt,axis=1))(sentence_embeddings)

    return keras.Model([input_ids,token_type_ids,attention_mask],normalized_sentence_embeddings,name='sentence_embedding_model')

# %%
sentence_embedding_model = convert_bert_to_sentence_embedding_model(model)

# %%
def create_siamese_model(sentence_embedding_model):
    s1_input_ids = keras.Input(shape=(None,),dtype=tf.int32)
    s1_token_type_ids = keras.Input(shape=(None,),dtype=tf.int32)
    s1_attention_mask = keras.Input(shape=(None,),dtype=tf.int32)
    s2_input_ids = keras.Input(shape=(None,),dtype=tf.int32)
    s2_token_type_ids = keras.Input(shape=(None,),dtype=tf.int32)
    s2_attention_mask = keras.Input(shape=(None,),dtype=tf.int32)

    s1_embeddings = sentence_embedding_model([s1_input_ids,s1_token_type_ids,s1_attention_mask])
    s2_embeddings = sentence_embedding_model([s2_input_ids,s2_token_type_ids,s2_attention_mask]) 
    stack_embeddings = keras.layers.Lambda(lambda x: tf.stack(x,axis=1))([s1_embeddings,s2_embeddings])
    return keras.Model([s1_input_ids,s1_token_type_ids,s1_attention_mask,s2_input_ids,s2_token_type_ids,s2_attention_mask],stack_embeddings)

# %%
siamese_model = create_siamese_model(sentence_embedding_model)

# %%
siamese_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, None)]       0           []
#
#  input_5 (InputLayer)           [(None, None)]       0           []
#
#  input_6 (InputLayer)           [(None, None)]       0           []
#
#  input_7 (InputLayer)           [(None, None)]       0           []
#
#  input_8 (InputLayer)           [(None, None)]       0           []
#
#  input_9 (InputLayer)           [(None, None)]       0           []
#
#  sentence_embedding_model (Func  (None, 768)         102267648   ['input_4[0][0]',
#  tional)                                                          'input_5[0][0]',
#                                                                   'input_6[0][0]',
#                                                                   'input_7[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_9[0][0]']
#
#  lambda_1 (Lambda)              (None, 2, 768)       0           ['sentence_embedding_model[0][0]'
#                                                                  , 'sentence_embedding_model[1][0]
#                                                                  ']
#
# ==================================================================================================
# Total params: 102,267,648
# Trainable params: 102,267,648
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
@tf.function
def negative_ranking_loss_func(_, embeddings):
    query_embeddings,question_embeddings = embeddings[:,0],embeddings[:,1]
    # tf.print('min in embedding',tf.reduce_min(query_embeddings))
    score_matrix = tf.linalg.matmul(query_embeddings,tf.transpose(question_embeddings))
    # tf.print('min in loss',tf.reduce_min(score_matrix))
    labels = tf.one_hot(tf.range(len(embeddings)), len(embeddings))
    loss = tf.nn.softmax_cross_entropy_with_logits(labels,score_matrix*10)
    return loss

adam_opt = keras.optimizers.Adam(learning_rate=2e-5)
siamese_model.compile(loss=negative_ranking_loss_func, optimizer=adam_opt)

# %% [markdown]
# ## 模型训练

# %%
s1_input_ids = s0_encoded['input_ids']
s1_token_type_ids = s0_encoded['token_type_ids']
s1_attention_mask = s0_encoded['attention_mask']
s2_input_ids = s1_encoded['input_ids']
s2_token_type_ids = s1_encoded['token_type_ids']
s2_attention_mask = s1_encoded['attention_mask']
y_placeholder = tf.ones(len(s1_input_ids),dtype=tf.bool)

# %%
def check_accuracy_manually(model,data_group):
    dev_s1_input_ids,dev_s1_token_type_ids,dev_s1_attention_mask,dev_s2_input_ids,dev_s2_token_type_ids,dev_s2_attention_mask,dev_labels = data_group
        
    embeddings = np.asarray(model.predict([dev_s1_input_ids,dev_s1_token_type_ids,dev_s1_attention_mask,dev_s2_input_ids,dev_s2_token_type_ids,dev_s2_attention_mask]))
    queries_embeddings = embeddings[:,0]
    questions_embeddings = embeddings[:,1]
    scores = tf.linalg.matmul(queries_embeddings,tf.transpose(questions_embeddings))
    scores = tf.linalg.diag_part(scores)
    predict_labels = tf.math.greater(scores,0.5)
    # tf.print('min',tf.reduce_min(scores))
    return tf.math.reduce_mean(tf.cast(tf.math.equal(predict_labels,dev_labels),tf.float32))
    

class CalcAccuracyCallback(keras.callbacks.Callback): 
    def __init__(self,val_data):
        super(keras.callbacks.Callback, self).__init__()
        self.val_data = val_data 
    def on_epoch_end(self, epoch, logs=None):
        accuracy = check_accuracy_manually(self.model,self.val_data)
        tf.print("accuracy on dev set is ",accuracy)

# %%
siamese_model.fit([s1_input_ids,s1_token_type_ids,s1_attention_mask,s2_input_ids,s2_token_type_ids,s2_attention_mask],y_placeholder,
                  # validation_data = ([dev_s1_input_ids,dev_s1_token_type_ids,dev_s1_attention_mask,dev_s2_input_ids,dev_s2_token_type_ids,dev_s2_attention_mask],dev_labels),
                  callbacks=[CalcAccuracyCallback((s1_input_ids[:1000],s1_token_type_ids[:1000],s1_attention_mask[:1000],s2_input_ids[:1000],s2_token_type_ids[:1000],s2_attention_mask[:1000],y_placeholder[:1000])),
                            CalcAccuracyCallback((dev_s1_input_ids,dev_s1_token_type_ids,dev_s1_attention_mask,dev_s2_input_ids,dev_s2_token_type_ids,dev_s2_attention_mask,dev_labels))],
                  epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 331/331 [==============================] - ETA: 0s - loss: 0.4485min 0.432966948
# accuracy on dev set is  0.993
# min -0.211176127
# accuracy on dev set is  0.483549595
# 331/331 [==============================] - 174s 444ms/step - loss: 0.4485
# Epoch 2/10
# 331/331 [==============================] - ETA: 0s - loss: 0.2429min 0.376758486
# accuracy on dev set is  0.995
# min -0.207627222
# accuracy on dev set is  0.512279868
# 331/331 [==============================] - 144s 434ms/step - loss: 0.2429
# Epoch 3/10
#   2/331 [..............................] - ETA: 1:58 - loss: 0.2177
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 siamese_model.fit([s1_input_ids,s1_token_type_ids,s1_attention_mask,s2_input_ids,s2_token_type_ids,s2_attention_mask],y_placeholder,
#       2                   # validation_data = ([dev_s1_input_ids,dev_s1_token_type_ids,dev_s1_attention_mask,dev_s2_input_ids,dev_s2_token_type_ids,dev_s2_attention_mask],dev_labels),
#       3                   callbacks=[CalcAccuracyCallback((s1_input_ids[:1000],s1_token_type_ids[:1000],s1_attention_mask[:1000],s2_input_ids[:1000],s2_token_type_ids[:1000],s2_attention_mask[:1000],y_placeholder[:1000])),
#       4                             CalcAccuracyCallback((dev_s1_input_ids,dev_s1_token_type_ids,dev_s1_attention_mask,dev_s2_input_ids,dev_s2_token_type_ids,dev_s2_attention_mask,dev_labels))],
#       5                   epochs=10,batch_size=32)
#
# File ~/miniconda3/envs/training2022/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/training2022/lib/python3.9/site-packages/keras/engine/training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1377 with tf.profiler.experimental.Trace(
#    1378     'train',
#    1379     epoch_num=epoch,
#    1380     step_num=step,
#    1381     batch_size=batch_size,
#    1382     _r=1):
#    1383   callbacks.on_train_batch_begin(step)
# -> 1384   tmp_logs = self.train_function(iterator)
#    1385   if data_handler.should_sync:
#    1386     context.async_wait()
#
# File ~/miniconda3/envs/training2022/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/training2022/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/training2022/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/miniconda3/envs/training2022/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2956, in Function.__call__(self, *args, **kwargs)
#    2953 with self._lock:
#    2954   (graph_function,
#    2955    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956 return graph_function._call_flat(
#    2957     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniconda3/envs/training2022/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/training2022/lib/python3.9/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/training2022/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
# siamese_model.fit([s1_input_ids,s1_token_type_ids,s1_attention_mask,s2_input_ids,s2_token_type_ids,s2_attention_mask],y_placeholder,
#                   validation_data = ([dev_s1_input_ids,dev_s1_token_type_ids,dev_s1_attention_mask,dev_s2_input_ids,dev_s2_token_type_ids,dev_s2_attention_mask],dev_labels),
#                   callbacks=[CalcAccuracyCallback((dev_s1_input_ids,dev_s1_token_type_ids,dev_s1_attention_mask,dev_s2_input_ids,dev_s2_token_type_ids,dev_s2_attention_mask,dev_labels))],
#                   epochs=100,batch_size=16)

# %%
sentence1 = "今天下午可能会下雨"
sentence2= '今天天气很晴朗'
sentence3= '天气预报说下午有雨'
sentence4= '北京是中国的首都'

sentence_list = [sentence1,sentence2,sentence3,sentence4]
encoded_inputs = tokenizer(sentence_list,return_tensors='tf',padding=True)
sentence_embeddins = sentence_embedding_model(encoded_inputs)
for i,s1 in enumerate(sentence_list):
    for j,s2 in enumerate(sentence_list):
        print(f'[{s1}]和[{s2}]的相似度为：',np.matmul(sentence_embeddins[i], tf.transpose(sentence_embeddins[j])))

# %%
correct_count = 0
for (s1,s2),label in zip(dev_sentence_pairs,dev_labels):
    s1_embedding = sentence_embedding_model(tokenizer(s1,return_tensors='tf',padding=True,truncation=True,max_length=MAX_LEN),training=False)[0]
    s2_embedding = sentence_embedding_model(tokenizer(s2,return_tensors='tf',padding=True,truncation=True,max_length=MAX_LEN),training=False)[0]
    print(f'[{label}][{s1}]和[{s2}]的相似度为：',np.matmul(s1_embedding, s2_embedding))
    if (np.matmul(s1_embedding, s2_embedding)>0.5) ==label :
        correct_count+=1
        print('!!!')
print(correct_count)
# Out:
# [False][双十一花呗提额在哪]和[里可以提花呗额度]的相似度为： 0.99999654
# [False][花呗支持高铁票支付吗]和[为什么友付宝不支持花呗付款]的相似度为： 0.9295593
# [True][我的蚂蚁花呗支付金额怎么会有限制]和[我到支付宝实体店消费用花呗支付受金额限制]的相似度为： 0.94713557
# !!!
# [False][为什么有花呗额度不能分期付款]和[花呗分期额度不足]的相似度为： 0.9656383
# [False][赠品不能设置用花呗付款]和[怎么不能花呗分期付款]的相似度为： 0.7830473
# [True][为什么这个订单不可以花呗支付]和[为什么支付时没有出现用花呗支付]的相似度为： 0.8588219
# !!!
# [False][使用了花呗没有记录]和[银行扣了，还款，花呗]的相似度为： 0.9899275
# [False][一个身份证能办几个花呗]和[花呗身份验证为何不亮]的相似度为： 0.9406398
# [False][花呗咋扫不上]和[花呗扫一扫不能付钱]的相似度为： 0.78438926
# [False][我的花呗额度为什么还没有增长]和[为什么花呗额度才有***块]的相似度为： 0.95101166
# [True][花呗收款额度限制]和[收钱码，对花呗支付的金额有限制吗]的相似度为： 0.9164518
# !!!
# [False][为什么我的借呗跟花呗不见了]和[我现在登陆后以前的花呗，借呗，余额宝里的钱都不见了怎么办]的相似度为： 0.9557075
# [True][我的账号是新号，为什么花呗是以前的号码]和[花呗号吗是以前的号码]的相似度为： 0.7657628
# !!!
# [False][花呗提前分期利息怎么算]和[花呗分期提前结清会有手续费吗]的相似度为： 0.69271183
# [False][记错借呗的还款日期 这几天没去注意 怎么办]和[支付借呗怎么修改还款日期]的相似度为： 0.83016014
# [False][***月份的花呗为什么出现在***月份的账单里]和[花呗的往期账单怎么查]的相似度为： 0.8865557
# [False][为什么借呗开通了又自动关闭了]和[还了钱关闭借呗]的相似度为： 0.9068506
# [False][为什么借呗会收回去]和[为什么我这次借呗利益这么高]的相似度为： 0.9116498
# [False][蚂蚁借呗能自己还钱吗]和[借呗还钱设置卡]的相似度为： 0.9090432
# [True][之前有逾期账单，，什么时候才能用花呗]和[花呗逾期后多久能用]的相似度为： 0.92704415
# !!!
# [True][花呗遇期了我以都还清了怎么还不能使用]和[花呗已还清，还是不能使用]的相似度为： 0.9639596
# !!!
# [False][可是我不喜欢这个网商贷款]和[不想要网贷商，给我关闭吧]的相似度为： 0.9999999
# [True][我开通花呗的手机号坏了，现在换了手机号怎么找回原来的号]和[我以前的号码开通的支付宝，然后号码不用了，现在我开花呗要用不用的号码，能解决么]的相似度为： 0.9044168
# !!!
# [False][借呗开下呗]和[开通借呗年龄]的相似度为： 0.96613985
# [True][可以关闭花呗]和[来关闭花呗]的相似度为： 0.9140036
# !!!
# [False][我的商家花呗收钱码为什么不能开通]和[花呗还清了，为啥还是不能开通]的相似度为： 0.96401936
# [False][支付宝里找不到花呗]和[怎么找不到花呗页面]的相似度为： 0.89935637
# [False][花呗显示另一个号码已开通花呗怎么办]和[我的蚂蚁花呗在另一个号，号我忘了怎么办]的相似度为： 0.9999974
# [True][借呗授权取消了还能再次授权借呗吗]和[借呗授权不小心关闭还能在授权吗]的相似度为： 0.9802022
# !!!
# [False][怎么用蚂蚁借呗]和[怎么样才可以用借呗]的相似度为： 0.9160031
# [False][借呗升级网商贷要多少时间]和[网商贷跳至借呗]的相似度为： 0.85846674
# [False][我为什么还没发使用花呗]和[我怎么没有蚂蚁花呗]的相似度为： 0.9510355
# [True][帮我把借呗提额吧！不够用]和[借呗用了一年了。一点额度不给提]的相似度为： 0.944709
# !!!
# [False][我在国外才回国钱己还完可以开通花呗吗]和[能把我花呗开通吗]的相似度为： 0.9604448
# [False][为什么我的花呗还清了还在让我还]和[退款成功了为什么还要扣我花呗的钱]的相似度为： 0.94460917
# [True][花呗提示未出账，还款是什么时候还]和[今天用花呗买了 什么时候还款]的相似度为： 0.952862
# !!!
# [True][订单退款成功了，为什么仍然要还花呗]和[退款到了花呗，为什么还要还款]的相似度为： 0.96058404
# !!!
# [False][怎么解除借呗的详细信息]和[怎么把借呗记录删除]的相似度为： 0.90907437
# [False][我用花呗交了电费，咋办]和[交电费用花呗不给积分]的相似度为： 0.93383825
# [True][为什么用花呗付款了，显示没付款]和[花呗支付，显示未付款]的相似度为： 0.9294895
# !!!
# [True][我的蚂蚁花呗自动还款失败，可是银行卡的钱被扣了，那我是还还了吗]和[花呗自动还款失败，但款没退回]的相似度为： 0.9276732
# !!!
# [False][我是买家扫码了，显示不支持花呗支付]和[使用花呗支付为什么都是显示不支持花呗付款]的相似度为： 0.94175017
# [True][开通了花呗可以取消吗]和[我可以取消蚂蚁花呗吗]的相似度为： 0.83854425
# !!!
# [True][花呗分期中，下月可以再次分期吗]和[花呗账单分期了，下个月还可以分期么]的相似度为： 0.9640343
# !!!
# [True][蚂蚁花呗自动还款怎么会有手续费]和[花呗自动还款收取手续费]的相似度为： 0.9657266
# !!!
# [True][借呗分期为什么没有***期选项]和[借呗为什么不能分***期可]的相似度为： 0.92938477
# !!!
# [False][我的收钱码，花呗支付扣点太多了]和[收钱码花呗收款]的相似度为： 0.8381109
# [False][用蚂蚁花呗怎支付]和[淘宝付款想用花呗怎么弄]的相似度为： 0.8519063
# [True][使用花呗有风险吗]和[花呗安全吗]的相似度为： 0.80098367
# !!!
# [False][怎么查看花呗的消费明细]和[已自动还款的花呗明细怎么查看]的相似度为： 0.9092314
# [False][蚂蚁花呗分期中还能在分期吗]和[我要还花呗的分期]的相似度为： 0.92120796
# [False][我的花呗为啥不能提前还]和[花呗额度用完了，提前还款不能再用]的相似度为： 0.94163406
# [False][花呗还款可以原路返回吗]和[如果还款完的话，可以取消花呗吗]的相似度为： 0.9212613
# [True][打开花呗提示邮箱登陆]和[花呗为什么要我用邮箱登陆]的相似度为： 0.9467981
# !!!
# [False][花呗额度用完 还可以欠吗]和[花呗额度下个月还有吗]的相似度为： 0.9999972
# [True][网商贷转换借呗]和[如何将网商贷换成气借呗]的相似度为： 0.9192841
# !!!
# [True][花呗单笔限制额度]和[蚂蚁花呗单笔交易限制额度]的相似度为： 0.90496624
# !!!
# [False][花呗临时额度有效期到会怎么样]和[花呗不是有临时额度吗,如果想用临时额度是不是在有效期限内还上还是]的相似度为： 0.95225346
# [False][开通蚂蚁花呗需要多少额度]和[花呗体验额度能多少钱]的相似度为： 0.7983777
# [True][怎么花呗不能使用刷脸]和[花呗耍不了脸]的相似度为： 0.8133019
# !!!
# [False][*** 花呗返现]和[***月份，花呗返现]的相似度为： 0.99997264
# [False][分期购买商品花呗额度必须和额度一样吗]和[花花呗分期购买商品额度不够怎么办]的相似度为： 0.9538735
# [True][为什么我的花呗额度是五千五，我还了两千九百多，现在为什么还要还四千多]和[为什么花呗的钱还款了还有那么多]的相似度为： 0.9564945
# !!!
# [True][马蚁借呗怎么借]和[用蚂蚁借呗怎么借钱]的相似度为： 0.7844458
# !!!
# [False][花呗收钱还在审核中要多久才能开通]和[我现在怎么才能快点开通花呗]的相似度为： 0.79873586
# [False][怎样查询蚂蚁花呗还款款项]和[花呗 利息怎么查询]的相似度为： 0.95272243
# [True][借呗多久到f帐]和[蚂蚁借呗要等多久才能到卡上]的相似度为： 0.96572286
# !!!
# [False][花呗里面的钱是不是自己的]和[花呗是不是先花后还]的相似度为： 0.90910876
# [True][花呗能不能扫码支付]和[使用花呗付款可以扫码吗]的相似度为： 0.8133846
# !!!
# [False][为什么蚂蚁花呗绑定银行卡绑定不了]和[申请花呗已经绑定银行卡、显示不了银行卡]的相似度为： 0.9568231
# [True][蚂蚁借呗的借款记录]和[蚂蚁借呗账单明细]的相似度为： 0.95914686
# !!!
# [False][蚂蚁借呗还一期还能借出来吗]和[可以一个月还清吗？借蚂蚁借呗的钱]的相似度为： 0.984625
# [False][我这月花了六百多 花呗上显示这个月我只需还四百多]和[我刚刚用了花呗两百多，是这个月***号还？还是下个月***号]的相似度为： 0.93340176
# [False][借呗会不会恢复***期借款]和[借呗什么时候恢复期***个月还款]的相似度为： 0.9742258
# [False][支付宝还花呗可以自动吗]和[花呗逾期不自动还款吗]的相似度为： 0.91399324
# [False][几号以后用花呗，是次月还]和[***月***号用花呗 几号还]的相似度为： 0.9516852
# [True][花呗已经付完钱 淘宝订单还显示没付款]和[这边订单显示没有付款，但是钱花呗扣了]的相似度为： 0.90510106
# !!!
# [False][借呗怎么用额度提高]和[花呗消费额度怎么提升]的相似度为： 0.9750372
# [False][小蓝车还支持花呗付押金吗]和[花呗付款的小蓝押金什么时候退]的相似度为： 0.94482607
# [False][花呗最低还款一个月还几次]和[花呗有没有最低还款的限制]的相似度为： 0.92615676
# [False][蚂蚁借呗显示无信用记录]和[一直在使用支付宝，为啥借呗上面显示无记录]的相似度为： 0.94966865
# [False][蚂蚁借呗，额度较低，如何提升]和[怎么提升借呗和发呗的额度]的相似度为： 0.92622226
# [False][借呗负面记录怎么办]和[忘记换借呗，预期怎么办]的相似度为： 0.9192897
# [True][花呗 在那款]和[我的花呗在那里找呀]的相似度为： 0.91593754
# !!!
# [False][蚂蚁借呗还款后还有额度吗]和[蚂蚁借呗还了钱为什么没有恢复额度]的相似度为： 0.93465143
# [True][我己经买了，假如我钱还给花呗了，我在退票钱会退在那里去]和[我用花呗付钱，但是我用自己的钱还了，额度就满了，但是我退货退款之后钱去了哪里]的相似度为： 0.96160346
# !!!
# [False][花呗分期可以提前还清一半吗]和[花呗分期了怎样提前还完]的相似度为： 0.9495027
# [True][我的花呗到期了没钱还款会受到什么影响没有]和[花呗逾期一两有什么影响]的相似度为： 0.9337483
# !!!
# [True][退款成功，花呗没有收到钱怎么回事]和[退给花呗的钱怎么能看到，为什么还不到账]的相似度为： 0.91364247
# !!!
# [False][借呗还款怎么成***个月了]和[蚂蚁借呗只能用***个月还]的相似度为： 0.8769238
# [False][借呗分期还了可以在提出来吗]和[借呗借的时候没分期 还能分期吗]的相似度为： 0.92973864
# [True][我都花呗为什么不能用]和[为什么我的花呗没办法使用]的相似度为： 0.8384215
# !!!
# [False][借呗。借完钱了。 没有分期。 还的时候有分期吗]和[借呗借了钱能不能分期还]的相似度为： 0.9510292
# [True][借呗能延一期还吗]和[借呗我这边到期了。能不能延期]的相似度为： 0.91604835
# !!!
# [False][我要开通收款花呗怎么开通]和[个体经营开通花呗收款店面照片]的相似度为： 0.94527864
# [False][花呗借呗怎么都不提额了]和[满意花呗怎么提升额度]的相似度为： 0.9494903
# [True][花呗可以转移到我本人另一个支付宝吗]和[能不能把花呗转到另外个支付宝账号]的相似度为： 0.9657443
# !!!
# [True][两个支付宝账号 花呗不能通用吗]和[花呗能不能多个账户使用]的相似度为： 0.9526973
# !!!
# [False][我这个咋没借呗]和[借呗还提醒我没还款成功]的相似度为： 0.8415208
# [False][花呗逾期什么时候消除]和[花呗负面消息怎么消除]的相似度为： 0.89099014
# [False][在？问花呗还款事情]和[请我花呗还款有宽限期吗]的相似度为： 0.8299967
# [False][怎么删除借呗聊天记录]和[借呗已关闭，借款记录能删除吗]的相似度为： 0.91917545
# [False][花呗分期之后不能提前两个月还钱吗]和[我的蚂蚁花呗分期为什么不能提前还款]的相似度为： 0.9675914
# [False][借呗分期可以提前还款吗]和[借呗，我提前还款]的相似度为： 0.9337797
# [False][借呗申请没有通过]和[我的蚂蚁借呗没通过什么时候在申请]的相似度为： 0.96042943
# [False][花呗还清多余的钱怎么不退回余额]和[什么用这么多？我的支付宝有钱什么还用花呗]的相似度为： 0.9293833
# [False][为什么我的花呗一个月了还在评估，还不能使用]和[怎么不能用花呗了]的相似度为： 0.9034202
# [True][花呗哪里可以充值电话费]和[话费在花呗哪里冲]的相似度为： 0.9159887
# !!!
# [False][借呗怎么不能解借了]和[为什么我借呗也过不了]的相似度为： 0.9606161
# [False][花呗能不能在别的账号开通]和[以前号没用了，现在的号可以开花呗嘛]的相似度为： 0.9190395
# [True][多少信用分可以用蚂蚁借呗]和[借呗多少信用分才能开通呀]的相似度为： 0.9447626
# !!!
# [False][我想咨询一下我的蚂蚁花呗什么时候可以用]和[我什么时候还可以使用花呗购物]的相似度为： 0.91930705
# [False][蚂蚁借呗，提前还款有手续费吗]和[借呗选择***个月，但如果提前还款，分期的几个月还会手续手续费吗]的相似度为： 0.93602
# [False][我以前用另一个号码绑定了花呗 现在这个号码登不了 能改吗]和[我之前用的账号登录使用的花呗如何绑定现在的支付宝账号呀]的相似度为： 0.93923366
# [False][借呗和网商贷的额度]和[借呗与网商贷一样吗]的相似度为： 0.9640303
# [False][我还款到花呗的钱，钱打到支付宝还是我的银行卡里]和[我用银行卡支付，却显示花呗。既扣我银行卡钱也扣我花呗钱]的相似度为： 0.98018235
# [True][不用花呗上面的钱，会不会扣利息]和[比如一年多没有用花呗，会不会扣年费]的相似度为： 0.9447412
# !!!
# [True][花呗能多次分期吗]和[蚂蚁花呗分期后能再分期吗]的相似度为： 0.99996936
# !!!
# [False][花呗红包和优惠券，购物津贴能一起用吗]和[使用购物津贴不能用花呗支付嘛]的相似度为： 0.9670809
# [True][用花呗买的，退款是怎样]和[花呗帐单怎么退款]的相似度为： 0.92826915
# !!!
# [False][我淘宝退钱退到花呗上了，会不会下月少还]和[我有个花呗的钱退我了]的相似度为： 0.91860247
# [False][借呗的钱可以干什么]和[我可以直接用支付宝余额还借呗的钱吗]的相似度为： 0.7981181
# [True][花呗分期对信用有影响嘛]和[花呗分期对信誉有影响吗]的相似度为： 0.7736987
# !!!
# [False][花呗的计算周期是什么]和[计算花呗总花费]的相似度为： 0.9159112
# [False][花呗还款后还可以分期吗]和[蚂蚁花呗最低还款后还能不能分期]的相似度为： 0.9027106
# [False][花呗绑定另外支付宝账号]和[花呗能绑定到另一个手机号么]的相似度为： 0.74137217
# [False][蚂蚁借呗分十二期还款怎么弄]和[现在蚂蚁借呗怎么贷款为***个月了期限了]的相似度为： 0.93726397
# [True][蚂蚁借呗没了出现了个网商贷]和[借呗变成了商网贷]的相似度为： 0.9259136
# !!!
# [False][花呗还款要利息嘛]和[花呗扣利息吗]的相似度为： 0.81341106
# [False][借呗自动还款顺序怎么调整]和[花呗借呗的还款顺序是]的相似度为： 0.9606559
# [False][怎么我用了花呗分期购买，怎么还是一下扣钱了]和[花呗分期怎么扣款]的相似度为： 0.72839785
# [False][为什么我下月应还已经变成零了但我想关闭花呗时提示还有***没有还]和[花呗已经还了为什么显示没有还]的相似度为： 0.9390849
# [False][花呗怎么还欠费]和[钱我交了！花呗怎么还显示缴费中]的相似度为： 0.9999298
# [False][蚂蚁借呗超期一天还有影响吗]和[改名字对蚂蚁花呗和借呗有影响吗]的相似度为： 0.9750966
# [True][蚂蚁花呗逾期以后多久才能正常使用]和[上次花呗逾期了，要多久才能允许使用]的相似度为： 0.95921695
# !!!
# [False][为什么提前还款会关闭借呗]和[借呗提前还款还要利息吗]的相似度为： 0.9549689
# [False][蚂蚁借呗还款日最迟几点还款]和[蚂蚁借呗的钱今天到了还款日，但是钱不够，能晚点还吗]的相似度为： 0.93570614
# [True][蚂蚁借呗借半年什么时候还款]和[我的借呗还款时间]的相似度为： 0.9527262
# !!!
# [False][花呗在台湾可以用吗]和[蚂蚁花呗可以在店里使用吗]的相似度为： 0.7844493
# [True][蚂蚁花呗可以免费提现额度]和[花呗有***的免费提现额度]的相似度为： 0.94124776
# !!!
# [False][点开花呗提示我登入以前的账号 账号忘记了怎么办]和[之前的花呗账号忘记了]的相似度为： 0.92086565
# [True][我的借呗只能用***个月]和[蚂蚁借呗为什么最多只能借六个月]的相似度为： 0.80115414
# !!!
# [True][花呗还款，只要在最后还款日前还了就可以是么]和[花呗***日还款是指***日的***时之前都可以吗]的相似度为： 0.92149436
# !!!
# [False][使用花呗人脸识别不了怎么办]和[花呗要人脸识别 识别不了怎么回事]的相似度为： 0.9574969
# [False][我的蚂蚁花呗号码怎么改]和[蚂蚁花呗怎么修改学历信息]的相似度为： 0.8135089
# [False][付了款的订单，退款到了花呗]和[花呗还完了，退款退到了花呗怎么看不到]的相似度为： 0.92831707
# [False][手机号更换，蚂蚁借呗信用怎么换过来]和[借了借呗，想换绑定手机号码]的相似度为： 0.9510389
# [False][花呗自动还钱会影响额度信誉吗]和[花呗还款逾期两天有影响吗]的相似度为： 0.929687
# [False][我开通信用卡花呗收款了吗]和[已经开通花呗收款但是没法用]的相似度为： 0.91403717
# [True][我的花呗跟支付宝怎么老是提示账号存在风险]和[为什么我的淘宝里面登陆花呗提示支付宝有安全隐患]的相似度为： 0.9373551
# !!!
# [False][花呗钥匙怎么玩]和[花呗分期怎么才能用]的相似度为： 0.81353235
# [False][现在还可以吗蚂蚁花呗]和[加汽油可以用花呗吗]的相似度为： 0.8950106
# [False][我是问没开通花呗能不能使用购物津贴]和[花呗分期付尾款如何使用购物津贴]的相似度为： 0.89321685
# [True][我十一月一号用的花呗 什么时候还款]和[我这个月八号用了花呗，下个月什么时候还]的相似度为： 0.91916513
# !!!
# [False][我现在没钱还花呗怎么办]和[花呗钱越还越多]的相似度为： 0.9406277
# [False][我可以使用花呗吗]和[花呗能在支付宝使用吗]的相似度为： 0.8012232
# [True][可以用自己的支付宝为别人的花呗还款吗]和[花呗的钱可以让其他人代还吗]的相似度为： 0.8310722
# !!!
# [False][明明是余额支付的，为什么花呗也要还钱]和[为什么我这单消费是余额宝支付，花呗账单里还要还款]的相似度为： 0.9374325
# [False][我不想开通花呗？支付宝不能支付款]和[我怎么不可以开通花呗]的相似度为： 0.9999721
# [False][蚂蚁花呗提醒我积分过期]和[怎样查看到期花呗积分]的相似度为： 0.928301
# [True][怎么接触冻结花呗]和[花呗冻结了还能解冻吗]的相似度为： 0.9192994
# !!!
# [True][就想提升蚂蚁借呗额度]和[我想提升我的蚂蚁借呗]的相似度为： 0.9649618
# !!!
# [True][我觉得我附和条件，还是开不了花呗，什么情况]和[为什么我现在还不能开通蚂蚁花呗]的相似度为： 0.9421586
# !!!
# [False][蚂蚁借呗具体时间怎么算]和[借呗的利息是怎么算的]的相似度为： 0.9801728
# [False][借呗还款能分几期还]和[借呗，只能分几期来还款]的相似度为： 0.98284054
# [True][花呗临时额度账单能不能分期]和[我花呗临时提升的额度可以分期还款吗]的相似度为： 0.97504115
# !!!
# [True][花呗每个月什么时候确定账单]和[花呗是每个月几号结账]的相似度为： 0.9467828
# !!!
# [False][优先使用花贝怎么取消]和[怎么能取消花贝]的相似度为： 0.928277
# [True][我想用借呗借点钱]和[想使用蚂蚁借呗 我现在在医院急用钱]的相似度为： 0.9258967
# !!!
# [False][付尾款可用花呗吗]和[花呗没有钱了可以透支付款吗]的相似度为： 0.9510471
# [True][花呗支持充加油卡不]和[加油卡充值可以使用蚂蚁花呗吗]的相似度为： 0.74099046
# !!!
# [False][花呗支付为什么稍微大一点金额就不能用了]和[我要用蚂蚁花呗支付怎么支付不了]的相似度为： 0.8142481
# [False][借呗提额后还会降吗]和[长时间不用蚂蚁借呗额度会下降吗]的相似度为： 0.89089334
# [False][付款方式上面就没有写着花呗，两个字]和[上面没有这个花，被和戒备，这两个功能]的相似度为： 0.9677881
# [False][我再用不了花呗了呀]和[不知道花呗怎么用 关于花呗的一点都不知道]的相似度为： 0.90342236
# [True][淘宝网花呗提示支付宝账存在安全风险]和[我的花呗存在安全风险]的相似度为： 0.9086274
# !!!
# [False][花呗分期商品付款后出现该交易不支持花呗]和[花呗交易分期退款规则]的相似度为： 0.91860247
# [False][在手机淘宝上扫码，支付宝花呗能付款吗]和[这收钱码，能用花呗付款嘛]的相似度为： 0.97502303
# [False][为什么我蚂蚁借呗没法身份验证]和[蚂蚁借呗二代身份证怎么不能完善信息]的相似度为： 0.9118829
# [False][花呗恢复进度]和[马上恢复花呗]的相似度为： 0.7828679
# [True][我的花呗收款二维码]和[商家花呗的二维码]的相似度为： 0.9999963
# !!!
# [False][怎么查看花呗能负多少额度]和[我的花呗额度怎么刚得***]的相似度为： 0.9247807
# [False][借呗的每月等额怎么提前还款]和[蚂蚁借呗借的钱，可以提前还款吗]的相似度为： 0.96058065
# [False][本月花呗还不上怎么办]和[花呗超时怎么办]的相似度为： 0.94065136
# [False][用花呗付款次月还要手续费吗]和[我使用花呗付款会收费用吗]的相似度为： 0.9417398
# [False][换手机号没法登录花呗了]和[换手机号登陆花呗]的相似度为： 0.96706754
# [True][我要取消花呗功能]和[怎么把花呗取消]的相似度为： 0.95001227
# !!!
# [True][不想要那么多花呗额度]和[我不想要那么多额度的花呗]的相似度为： 0.98016924
# !!!
# [True][花呗付账有限制]和[花呗付款额限制]的相似度为： 0.9510174
# !!!
# [True][为什么花呗还是旧号码]和[我是用新手机号登录的，可是花呗的号码为什么还是老号码]的相似度为： 0.90358716
# !!!
# [False][蚂蚁花呗不长利息最晚还钱日期是什么时候]和[蚂蚁花呗这个月用钱下个月还有利息么]的相似度为： 0.9671107
# [True][我怎么开通不起借呗]和[怎么无法开通蚂蚁借呗]的相似度为： 0.9510257
# !!!
# [False][花呗还款可以从余额宝里扣吗]和[余额宝的钱可以自动还花呗的钱吗]的相似度为： 0.8300992
# [False][借呗是怎么弄的]和[怎么在蚂蚁借呗借钱]的相似度为： 0.96494615
# [False][我换号了，要怎么才可以用花呗]和[用了花呗怎么返钱给你]的相似度为： 0.9593022
# [False][永和大王花呗权益怎么退款]和[蚂蚁花呗。 怎么退款都到蚂蚁花呗了]的相似度为： 0.9111628
# [False][我的蚂蚁花呗账户怎么被冻结]和[怎样把开通的花呗冻结]的相似度为： 0.9657128
# [True][我的花呗人脸识别不出]和[花呗人脸识别为什么一直失败 是本人]的相似度为： 0.9116333
# !!!
# [False][退款退到花呗里面了，怎么没有钱款显示]和[支付宝显示消息退款已到花呗，但是花呗里没有退款消息，钱也没多]的相似度为： 0.93745
# [True][借呗贷款期限为什么现在是***个月了]和[为什么蚂蚁借呗不能借***个月]的相似度为： 0.91921175
# !!!
# [False][为什么开了花呗，借呗不出]和[花呗已开通，现在打不开网页了]的相似度为： 0.9640722
# [False][怎么能支付花呗]和[app付款支持花呗吗]的相似度为： 0.80112404
# [False][为什么借呗借了还不到账]和[用蚂蚁借呗借钱什么时候能到账]的相似度为： 0.9606695
# [False][我花呗预期了还款后什么时候能用]和[花呗冻结以后什么时候可以再使用]的相似度为： 0.8553213
# [False][花呗在沃尔玛可以用吗]和[用花呗可以付现给好友么]的相似度为： 0.8797773
# [False][花呗收款怎么开通]和[我是想开通实体店的花呗]的相似度为： 0.95926774
# [False][花呗取消芝麻分授权有事吗]和[我取消了芝麻信用对花呗的授权，然后如何恢复]的相似度为： 0.91882455
# [True][花呗怎样才有临时额度]和[能否给点花呗临时额度]的相似度为： 1.0
# !!!
# [True][系统大概多久重新评估一次花呗]和[花呗综合评估多久久就评估]的相似度为： 0.9558993
# !!!
# [False][暂不能使用花呗说逾期]和[花呗逾期在还款之后无法使用，那什么时候能使用]的相似度为： 0.94452393
# [False][借呗还款转不到余额宝，里面怎么办]和[借呗还钱，余额宝转入不进去怎么办]的相似度为： 0.92480004
# [False][蚂蚁借呗，能不能给我个机会]和[给我看蚂蚁借呗]的相似度为： 0.9163348
# [False][蚂蚁借呗今日主动扣款我有自己主动换了一笔怎么还钱额度没变]和[我今天还了借呗！怎么就没有额度了？是不是还没有给我更新]的相似度为： 0.94038284
# [False][我已经退货了，为什么花呗账单上还在]和[花呗账单有什么用]的相似度为： 0.89489484
# [True][蚂蚁借呗逾期一天，也会影响信用记录吗]和[蚂蚁借呗逾期三天会怎么样]的相似度为： 0.97502303
# !!!
# [False][我不能用花呗付款是为什么]和[商家花呗怎么不管用]的相似度为： 0.9406276
# [False][这个共享单车怎么不能用花呗交押金了]和[话费充值怎么不能用花呗支付了]的相似度为： 0.74585223
# [True][能不能帮我女朋友还花呗]和[怎么才能让朋友帮忙还花呗]的相似度为： 0.9495156
# !!!
# [False][花呗那里显示可用额度***]和[花呗额度用完之后可以透支吗]的相似度为： 0.93390304
# [False][花呗分期后，如果我提前还款，后面每期的手续费还会一起算吗]和[花呗分期后提前还款，手续费怎么退]的相似度为： 0.93070376
# [False][借呗还款怎么不会自动扣款]和[绑定了两张卡 一张卡借呗另一张卡会自动还款]的相似度为： 0.8675555
# [False][我的花呗自动还款为什么失败，现手工登入也还不了]和[花呗自动还款失败后会怎样]的相似度为： 0.9170432
# [False][什么是到店花呗消费返现翻倍资格]和[***元购买到店花呗消费返现翻倍资格]的相似度为： 0.9220437
# [True][支付宝的花呗里转到鼻，其他账户上面吗]和[花呗能不能转到别的支付宝]的相似度为： 0.9036307
# !!!
# [False][我的花呗怎么不能用了]和[花呗怎么登录]的相似度为： 0.8133019
# [True][把花呗转到另一个支付宝账号怎么转]和[支付宝花呗如何转到另一个账号]的相似度为： 0.95473576
# !!!
# [False][花呗的额度]和[花呗额度不涨]的相似度为： 0.9139622
# [False][我使用花呗付手续费吗]和[使用花呗支付需要扣服务费吗]的相似度为： 0.9649989
# [False][我的花呗充值错了]和[用花呗充值话费充错号码了怎么办]的相似度为： 0.964805
# [False][我的花呗为啥已经分期了，还提醒我已经逾期了]和[我花呗都已经还完了怎么还让我还]的相似度为： 0.85864824
# [True][借呗第一次审核未通过]和[为什么审核借呗不通过]的相似度为： 1.0
# !!!
# [True][预定酒店是信用住 是不是就是用的花呗]和[信用住 蚂蚁花呗]的相似度为： 0.85564464
# !!!
# [False][花呗逾期影响芝麻分]和[花呗逾期办理]的相似度为： 0.9212235
# [False][这几天进我网店拍的客户，用花呗付款的都是到我的收钱码账单里]和[我申请的二维码不支持花呗付款吗]的相似度为： 0.89816964
# [True][蚂蚁花呗怎么不能提前还完全部的额度了]和[花被怎么提前还不了]的相似度为： 0.91117024
# !!!
# [False][能申请花呗临时额度吗]和[什么时候才有花呗临时额度]的相似度为： 0.94150954
# [False][如何让借呗冻结]和[蚂蚁借呗被冻结怎么办]的相似度为： 0.94065136
# [False][花呗分期负会不会影响]和[花呗透支会影响信用吗]的相似度为： 0.94063854
# [False][为什么我的花呗总是提不了额度]和[为什么花呗掉额度]的相似度为： 0.911599
# [True][我今天退的款退在花呗上为什么没看到钱]和[退回到花呗的钱没有看到]的相似度为： 0.9385854
# !!!
# [False][我怎么消费用不了借呗和花呗]和[花呗收钱怎么收不了钱]的相似度为： 0.9446489
# [False][为什么我分期了。不能使用花呗]和[为什么我还款不能花呗分期]的相似度为： 0.9072027
# [False][绑定花呗的手机号已经没用了]和[换了手机号，如何解绑另一个花呗]的相似度为： 0.96616775
# [False][我以前还了花呗***了，为什么显示没有还]和[花呗那可用额度显示的不就是所有的欠款么]的相似度为： 0.9325003
# [True][花呗分期免息兑换]和[在哪可以积分换花呗免息]的相似度为： 0.76602066
# !!!
# [False][没有开通花呗，怎么会有花呗额度]和[现在还没有开通花呗 可以查看花呗额度吗]的相似度为： 0.91127515
# [False][没有蚂蚁借呗，还有花呗]和[花呗可用没有借呗]的相似度为： 0.77348804
# [True][花呗办分期一次性还清]和[花呗分期后能一次给完吗]的相似度为： 0.7846564
# !!!
# [False][我已经把另一个花呗关闭了]和[花呗提示另一个账号]的相似度为： 0.9414996
# [True][我花呗是之前手机号码登录过，现在这个手机登录不了]和[就是原来用的手机号儿注册过蚂蚁花呗，然后现在用的这个手机号，就是没法用了]的相似度为： 0.9449525
# !!!
# [False][花呗是什么]和[为什么我的账号开通不了花呗]的相似度为： 0.7841109
# [False][为什么我没有花呗，余额没有没有提额]和[我已经开通，花呗收钱二维码，为什么不行]的相似度为： 0.96436226
# [False][我的账户是否开通花呗]和[我的花呗还有开通的可能吗]的相似度为： 0.999992
# [True][花呗分期额度不足***什么意思]和[花呗***元购分期付款，提示花呗额度不足]的相似度为： 0.91361505
# !!!
# [False][花呗回自动确认收货么]和[商家显示已经退回蚂蚁花呗 为什么花呗还在显示等待确认收货]的相似度为： 0.96503717
# [True][找不到花呗，签不了约]和[我的支付宝找不到你们花呗]的相似度为： 0.9037247
# !!!
# [True][花呗每天可以用几次]和[花呗一天只能消费几次]的相似度为： 0.7661853
# !!!
# [False][借呗还款怎么修改还款顺序]和[借呗怎么还款]的相似度为： 0.92437726
# [True][花呗什么时间能开]和[什么时候我能用花呗]的相似度为： 0.9640042
# !!!
# [True][我的银行卡也扣除了***元，花呗也扣除了***元]和[我明明银行卡的钱扣的银，怎么还给花呗]的相似度为： 0.9664711
# !!!
# [False][淘宝怎么不能用花呗吗]和[花呗可以用于淘宝吗]的相似度为： 0.7661853
# [True][我手机已经更换完了但是我花呗还钱还是需要原来手机号的验证码、怎么回事]和[我说的是我手机号码改了 改成功了 但刚刚还花呗还是要我以前的号码]的相似度为： 0.8846841
# !!!
# [False][花呗可以推迟一天还款]和[花呗可以推迟还款期吗]的相似度为： 0.9999999
# [False][花呗分期是按你自己的额度多少购买商品么]和[花呗分期付款是分期额度是什么意思]的相似度为： 0.9110985
# [False][花呗还款是什意思]和[问花呗老提醒还款是什么意思]的相似度为： 0.81365836
# [False][我的花呗被关了吗]和[我沒开通花呗]的相似度为： 0.9163834
# [False][为什么我的花呗账单从***直接变成***了]和[我这个月换了***的花呗而账单上只写了***是什么意思]的相似度为： 0.81824636
# [True][怎么样关闭微商贷款！开通借呗]和[网商贷关掉开借呗]的相似度为： 0.8595003
# !!!
# [False][借呗分期好不好]和[借呗最长多久分期]的相似度为： 0.999997
# [True][借呗提前还款为什么还不了]和[我的蚂蚁借呗不能提前还款了]的相似度为： 0.9261424
# !!!
# [False][您开通花呗了吗]和[如何看自己开通花呗了吗]的相似度为： 0.8949298
# [True][我是，我这个支付宝里面有个花呗，我打开的时候为什么一直显示是让我让我登录邮箱使用呀]和[为什么我的花呗要要邮箱打开]的相似度为： 0.9082717
# !!!
# [True][花呗收钱码怎么获得]和[怎么领取花呗收款码]的相似度为： 0.9140081
# !!!
# [False][我可以现在还花呗]和[怎么我的花呗不可以使用]的相似度为： 0.95104486
# [False][花呗线下支付会被限制吗]和[线下花呗支付]的相似度为： 0.9337371
# [False][我要关闭关闭花呗]和[给我取消帐号并关闭花呗]的相似度为： 0.94854474
# [False][搞不懂为什么我用不了借呗]和[蚂蚁借呗已经还的额度为什么不能再借了]的相似度为： 0.98019445
# [False][蚂蚁花呗 我为什么没有]和[为什么我的花呗现在没有了]的相似度为： 0.8009813
# [False][退款金额大于我花呗欠款 差额去哪里了]和[我花呗的退款额度去哪里了]的相似度为： 0.97387505
# [False][我等待你们支付宝，帮我关闭花呗的通知]和[只有你帮我终结花呗，我才能控制自己]的相似度为： 0.94960284
# [True][怎么提升借呗钱]和[怎样提升额度借呗到***万多]的相似度为： 0.9657191
# !!!
# [False][怎么能解开蚂蚁花呗]和[花呗冻结了以后怎么解冻]的相似度为： 0.8909881
# [True][嘀嘀打车能用花呗]和[花呗是否可以滴滴打车]的相似度为： 0.890881
# !!!
# [False][我用借呗一万，到时还多少]和[我的借呗这月还款额多少]的相似度为： 0.96498215
# [False][酒店用花呗可以吗]和[我买机票用花呗付款可以吗]的相似度为： 0.8008637
# [True][借呗怎么只能分六个月]和[蚂蚁借呗为什么最多只能分六期了]的相似度为： 0.8013147
# !!!
# [False][为什么花呗退款了还款额不变]和[花呗淘宝退款后金额没变怎么办]的相似度为： 0.9448211
# [False][蚂蚁借呗怎么能提高额度]和[蚂蚁借呗 为什么不能分***期]的相似度为： 0.7847488
# [True][我的花呗咋被冻结了，还没有到还款最后日期]和[我的花呗账户以被冻结]的相似度为： 0.92943543
# !!!
# [True][花呗还款可以微信支付吗]和[花呗怎么能微信支付]的相似度为： 0.8133846
# !!!
# [False][蚂蚁借呗什么时候开始***期还款周期]和[为什么我借呗的还款时间缩短了]的相似度为： 0.91941625
# [True][逾期过的还可以在试用花呗吗]和[花呗逾期还可不可以开通]的相似度为： 0.8135487
# !!!
# [False][蚂蚁借呗提前还款还要算利息吗]和[问借呗是一个月还利息的有吗]的相似度为： 0.7770657
# [True][我的蚂蚁花呗怎么找不到啦]和[我的花呗，在支付宝里找不到]的相似度为： 0.9406283
# !!!
# [False][蚂蚁借呗怎么提前还下月款]和[借呗为什么不能提前还每月的钱]的相似度为： 0.9445523
# [False][怎么退款没到花呗]和[花呗退款为什么没到余额]的相似度为： 0.8711712
# [True][我的花呗账已经还完了，为什么还有说欠钱]和[我已经还款了，为什么花呗显示我没还款]的相似度为： 0.90508235
# !!!
# [True][花呗咋不能付电费]和[为什么我的电费不能用花呗继续交了]的相似度为： 0.96071225
# !!!
# [False][用花呗能不能缴电费]和[花呗不会交电费了]的相似度为： 0.9649507
# [False][借呗额度不用会降低]和[我借呗额度降低了]的相似度为： 0.91402376
# [False][花呗没有还完可以用借呗吗]和[用借呗没有还清可以用花呗嘛]的相似度为： 0.95101523
# [True][花呗额度是满的，淘宝退款退到花呗之后花呗额度也没有涨，退的钱去哪里了]和[我用花呗买的衣服，现在退回了钱去哪里了]的相似度为： 0.9249943
# !!!
# [False][到店花呗返现]和[花呗境外返现什么时候到]的相似度为： 0.99993575
# [False][借呗的钱是银行提供德]和[我蚂蚁借呗的钱转到银行卡]的相似度为： 0.8945147
# [True][为什么我的花呗扫二维码 扫不了]和[花呗怎么不能扫付款二维码]的相似度为： 0.8008771
# !!!
# [False][现在还有花呗分期免息了嘛]和[蚂蚁花呗三期免息]的相似度为： 0.81327057
# [True][蚂蚁借呗申请人数太多]和[蚂蚁借呗申请的人太多，怎么办]的相似度为： 0.9036849
# !!!
# [False][临时花呗额度也可以分期么]和[花呗零时额度的还款]的相似度为： 0.9999807
# [True][什么时候评估完借呗]和[借呗多久可以评估完]的相似度为： 0.96574175
# !!!
# [False][是不是我的花呗不能用了]和[我么用过花呗好吗]的相似度为： 0.9192791
# [False][蚂蚁借呗申请过一次，没通过。***个月不能再申请吗]和[申请蚂蚁借呗没有签同意书能通过吗]的相似度为： 0.936111
# [False][蚂蚁借呗刷脸失败太多怎么办]和[花呗一直刷脸失败怎么办]的相似度为： 0.9999936
# [False][找不到花呗开通的入口]和[花呗账单哪来的]的相似度为： 0.8949653
# [False][怎么查看顾客购买扣掉的信用卡服务费 和花呗]和[信用卡，花呗服务费怎么回事]的相似度为： 0.9162538
# [True][我用花呗买的东西提前还款了，但是现在东西退货了，这钱去哪了？为什么我没有收到]和[我用花呗买的东西，但是又退回了，我没有在花呗上确认收货，花呗退回的钱显示了但是没有入账]的相似度为： 0.96785176
# !!!
# [False][凌晨到现在借呗放款怎么还没到]和[蚂蚁借呗放款到现在还没到]的相似度为： 0.94680035
# [True][我花呗的钱用去哪里了可以查吗]和[怎么看花呗是在哪里用钱的]的相似度为： 0.9248273
# !!!
# [True][另一个账户花呗关闭，新帐号多长时间能开通]和[这个号我什么时候能开通花呗]的相似度为： 0.91121155
# !!!
# [True][怎么可以关掉花呗]和[怎么注销花呗]的相似度为： 0.91594267
# !!!
# [False][怎么样能够使用蚂蚁借呗]和[我要使用借呗]的相似度为： 0.8181261
# [False][我要开通蚂蚁花呗]和[什么开通花呗]的相似度为： 0.9999883
# [False][企业支付宝开通花呗]和[我想开通卖家花呗]的相似度为： 0.9160119
# [False][可以线下使用花呗吗]和[香港可以使用蚂蚁花呗吗]的相似度为： 0.7737365
# [True][钱退回花呗为什么还要我还]和[退款成功，为什么我的花呗还欠着]的相似度为： 0.78276515
# !!!
# [True][花呗多长时间定期一次]和[系统多少时间进行花呗评估一次]的相似度为： 0.99997866
# !!!
# [False][为什么我花呗有额度，不能支付]和[为什么有些店铺不可以用花呗付款]的相似度为： 0.9658589
# [False][我花呗上个月的已清，为什么这个月还有下个月的账单]和[我为什么会有蚂蚁花呗]的相似度为： 0.9654903
# [False][蚂蚁借呗提升额度成功]和[我想提借呗额度]的相似度为： 0.9282673
# [False][蚂蚁借呗怎么不能改还款日]和[蚂蚁借呗如何更改日期]的相似度为： 0.7411491
# [True][余额宝自动扣款到花呗]和[怎样设置余额宝花呗自动还款]的相似度为： 0.8383072
# !!!
# [True][怎么把花呗换到另一个支付宝]和[怎么把花呗更换绑定的支付宝号]的相似度为： 0.9999991
# !!!
# [True][花呗上个月的为什么不能提前还款]和[花呗提前还还不到]的相似度为： 0.94008815
# !!!
# [False][蚂蚁借呗还钱是到期自动还钱吗]和[蚂蚁借呗怎样主动还款]的相似度为： 0.966468
# [True][我的花呗是被封了吗]和[我的花呗被冻结了为什么]的相似度为： 0.9510355
# !!!
# [True][借呗逾期没有还自动关闭了，怎么开通]和[蚂蚁借呗关闭了，怎么再开通]的相似度为： 0.9260189
# !!!
# [True][借呗怎么用不成]和[无法使用借呗，怎么办]的相似度为： 0.9656544
# !!!
# [True][花呗还款怎么设置余额宝自动代扣]和[余额宝，怎么设置自动还款花呗]的相似度为： 0.8912337
# !!!
# [False][我的花呗分几期]和[我们***月的花呗分期服务费发票还没收到]的相似度为： 0.9006282
# [False][借呗晚还一天会不会影响信用]和[借呗逾期会不会影响提额]的相似度为： 0.798538
# [False][我的花呗逾期半个月了 下个月还可以吗]和[花呗逾期了可以先开通使用吗]的相似度为： 0.9405664
# [False][领取了花呗临时额度怎么固定]和[领取临时花呗]的相似度为： 0.765695
# [False][花呗不可以住酒店了吗]和[酒店信用住用不了花呗]的相似度为： 0.7736857
# [False][我的那里为什么没有花呗]和[没有花呗的选择]的相似度为： 0.91919816
# [False][借呗还完贷款就没了额度]和[蚂蚁借呗没有额度了怎么办]的相似度为： 0.965747
# [False][用了这么多年了，为什么没有借呗额度]和[为什么用了几个月借呗还是一千多]的相似度为： 0.94168484
# [False][借呗少于五天利息怎么收]和[蚂蚁借呗利息高低不同是怎么定的]的相似度为： 0.9051906
# [True][借呗借款成功会有短信通知吗]和[借呗提是短信通知吗]的相似度为： 0.9049412
# !!!
# [False][花呗分期可以提前还款去]和[花呗能提前还完分期吗]的相似度为： 0.9670873
# [False][花呗分期利息是多少]和[花呗逾期没有还款是怎么计算利息的]的相似度为： 0.813145
# [False][花呗额度成负会影响吗]和[花呗会影响借呗额度]的相似度为： 0.9213567
# [False][花呗下月最低还款]和[如何取消花呗最低还款]的相似度为： 0.96493316
# [True][蚂蚁借呗是消费多少才能开通]和[什么条件才可以开通蚂蚁借呗]的相似度为： 0.9250498
# !!!
# [False][借呗提前还款到还款日了还会继续扣款吗]和[蚂蚁借呗单笔提前还款后到本月***号还会自动扣款吗]的相似度为： 0.9796698
# [False][如何用我的二维码支持花呗付款]和[支持花呗的商家]的相似度为： 0.87109786
# [False][怎样更改花呗绑定的支付宝号]和[我的支付宝蚂蚁花呗怎么更换支付宝]的相似度为： 0.95102406
# [False][打电话可以开通借呗不]和[关闭网商贷就可以开通蚂蚁借呗了吗]的相似度为： 0.8521279
# [False][我花呗已经还清了。为什么会无法使用]和[我以还清花呗逾期为什么借呗用不了]的相似度为： 0.9283114
# [True][花呗可以每月十五号还款么]和[花呗可以慢点还款吗]的相似度为： 0.9656705
# !!!
# [False][花呗怎么主动还款]和[花呗 邮政卡通 自动还款]的相似度为： 0.8949996
# [False][支持花呗的超市可以用吗]和[在超市买东西的时候，可以用花呗付款吗]的相似度为： 0.89440334
# [False][花呗临时额度每个月什么时候出现]和[花呗额度临时申请怎么申请]的相似度为： 0.9405912
# [False][提示暂不能开通花呗收款该怎么处理]和[花呗收款怎么不能开通]的相似度为： 0.96589774
# [True][花呗不花用出利息吗]和[在花呗上借款成功后，赞不使用会着利息吗]的相似度为： 0.83865577
# !!!
# [False][没有开通花呗要怎么还款]和[花呗没开通但是淘宝买东西时用的是花呗，怎么还款]的相似度为： 0.8543475
# [True][花呗临时额度到期了 怎么办]和[临时的花呗金额到时间后会怎么弄]的相似度为： 0.96574247
# !!!
# [True][为什么我不可以用蚂蚁借呗]和[为什么我的借呗不能用了]的相似度为： 0.9999981
# !!!
# [False][之前的花呗我换手机号码了之前的花呗还能用吗]和[我可以转换手机号登录花呗吗]的相似度为： 0.84631455
# [True][借呗还完什么时候可以恢复额度]和[账都还完了，借呗还没有恢复额度]的相似度为： 0.91028345
# !!!
# [False][不分期还款借呗会停吗]和[蚂蚁借呗还款日期能不能变更]的相似度为： 0.9163472
# [False][开通花呗，不用里面的钱]和[之前开通花呗的手机号不用了]的相似度为： 0.91646373
# [False][为什么我提交不了借呗资料]和[为何进不了借呗]的相似度为： 0.87114525
# [False][花呗分期到几号]和[花呗分期当月要付款吗]的相似度为： 0.7734864
# [False][怎样才能提高蚂蚁花呗的信誉额度]和[花呗的总额度怎么提升]的相似度为： 0.9509648
# [False][为什么我的没有花呗显示]和[我，我的没有花呗]的相似度为： 0.8182277
# [False][蚂蚁借呗几时到账]和[借呗的多长时间到账]的相似度为： 0.9606576
# [False][就花呗被停一年多]和[我的花呗被冻结一年多了]的相似度为： 0.916399
# [False][花呗为什么不能代付]和[花呗还款朋友代付]的相似度为： 0.8135391
# [True][蚂蚁花呗最晚几点]和[花呗最迟九号几点还款]的相似度为： 0.85527027
# !!!
# [True][借呗可以存进去就取出来吗]和[蚂蚁借呗分期付款还钱进去可以当天拿出来吗]的相似度为： 0.8944581
# !!!
# [False][花呗额度为什么是负的]和[我的花呗额度这么纸]的相似度为： 0.94062495
# [False][蚂蚁花呗积分兑换提现有效期是]和[花呗积分兑换的东西在那里]的相似度为： 0.7290206
# [False][是不是用支付宝余额还款]和[花呗余额不能拿来还款吗]的相似度为： 0.9091287
# [False][借呗分期后可以再次分期嘛]和[花呗可以申请二次分期吗]的相似度为： 0.9671061
# [False][淘宝绑定的支付宝用不了]和[为什么我的花呗绑不了淘宝]的相似度为： 0.96619046
# [True][花呗还清，退回花呗，退回的钱在那里]和[花呗的钱我已经还了，淘宝退回来的钱在哪里]的相似度为： 0.9804502
# !!!
# [True][花呗什么时候能还款]和[花呗还款日哪天]的相似度为： 0.92128134
# !!!
# [False][为什么提示退款方式是花呗，但是我银行卡没收到]和[花呗显示我还款，可我没收到货]的相似度为： 0.9260453
# [False][分期花呗可以提前换吗]和[花呗分期成功后可以修改花呗分期方式吗]的相似度为： 0.8527937
# [True][之前的支付宝账号花呗注销了 现在新的账户可以开通花呗吗]和[我不想用这个支付宝账号开通花呗啦，可以用别的支付宝账号开通吗]的相似度为： 0.9505445
# !!!
# [False][我的花呗不能开吗]和[我花呗还能不能开]的相似度为： 0.91400325
# [False][用支付宝支付就可以用花呗支付]和[支付宝没有开通花呗，别人可以用花呗向我付款吗]的相似度为： 0.9112292
# [False][花呗支付口碑商家限额多少]和[口碑商家能花呗付款吗]的相似度为： 0.8945147
# [False][所以说当时开通的花呗也一并关闭了是么]和[告诉我的***的这个电话号码，可不可以开通花呗，不是不可以开通的话，我就不开通了]的相似度为： 0.93805623
# [True][我的花呗关闭了，另一个也是我身份证开通的支付宝为什么开通不了花呗]和[我已经将其中一个账号的花呗关闭，为什么第二个账号仍然无法开通]的相似度为： 0.913395
# !!!
# [True][花呗，换最低额度可以吗]和[花呗还款最低限度]的相似度为： 0.89501107
# !!!
# [False][花呗和借呗不能一块使用吗]和[借呗还清可以用花呗吗]的相似度为： 0.8135706
# [True][一个多月了怎么还不能开通花呗借呗]和[我怎么开通不了花呗和蚂蚁借呗呀]的相似度为： 0.9136834
# !!!
# [True][蚂蚁花呗没还款结束能开通借呗吗]和[花呗没还完借呗就开不了吗]的相似度为： 0.8587023
# !!!
# [False][实名认证之后为什么开通不了花呗]和[怎么开不了花呗的]的相似度为： 0.903576
# [True][为什么我的借呗还了款没有恢复额度]和[为啥借呗我以还款，不恢复额度]的相似度为： 0.9374112
# !!!
# [False][借呗的剩余免费提现的额度，可以提出来吗]和[我借呗有提现额度为啥说没有额度可以借]的相似度为： 0.94669497
# [True][蚂蚁借呗要满足哪些条件]和[任何满足借呗条件]的相似度为： 0.91603357
# !!!
# [False][蚂蚁借呗按期还款不会产生不良记录]和[如果蚂蚁借呗还款逾期了怎么办]的相似度为： 0.9649731
# [True][可以使用微信零钱还花呗款吗]和[花呗用微信另钱还款]的相似度为： 0.99997133
# !!!
# [True][关闭花呗能否在开通]和[花呗a已关闭，怎么开通花呗b]的相似度为： 0.8517865
# !!!
# [False][蚂蚁借呗短信还款提醒]和[使用蚂蚁借呗时每次都会短信提醒 怎么取消短信提醒]的相似度为： 0.9620705
# [False][网商贷与借呗额度通用吗]和[借呗有没有占用银行贷款额度]的相似度为： 0.91876817
# [False][我不想取消使用花呗消费]和[***的花呗，给我取消吧]的相似度为： 0.9050528
# [True][怎么给我取消了借呗]和[为什么我的借呗被取消掉了]的相似度为： 0.92131925
# !!!
# [True][怎样取消额度（花呗），不用了]和[不想用花呗了]的相似度为： 0.79809225
# !!!
# [False][我的花呗能收钱，为什么信用卡不行]和[已经开通了花呗收款，为什么不可以用]的相似度为： 0.94175065
# [True][花呗使用不了]和[花呗被冻结]的相似度为： 0.81336653
# !!!
# [False][借呗银行卡可以更改吗]和[怎样更改借呗自动还款捆绑的银行卡]的相似度为： 0.8981213
# [True][蚂蚁花呗可以充话费吗]和[花呗能充值话费么]的相似度为： 0.96493316
# !!!
# [True][借呗怎么还没自动还款]和[蚂蚁借呗为什么到了还款日不自动还款]的相似度为： 0.94511795
# !!!
# [False][刚刚想交电费，发现付款不能用花呗了]和[花呗为什么不能使用]的相似度为： 0.7732806
# [False][花呗免息兑换在哪]和[花呗免息分期，说明]的相似度为： 0.7735523
# [True][如何把不用账号的花呗转到新的支付宝账号]和[怎么把支付宝花呗转转到另一个账号]的相似度为： 0.9342889
# !!!
# [False][在花呗分期还款提前还了未出账的一期需要手续费吗]和[花呗分期后提前还款，后面几个月的利息还算吗]的相似度为： 0.94717675
# [True][借呗逾期一天有影响么]和[花呗逾期两天受影响不]的相似度为： 0.9999999
# !!!
# [True][花呗如何填学历，没初中选]和[花呗哪个填学历哪个]的相似度为： 0.7660463
# !!!
# [True][双***花呗临时额度可以采用分期吗]和[花呗临时额度可以账单分期不]的相似度为： 0.97504115
# !!!
# [False][我要关闭这个蚂蚁借呗]和[昨晚我申请的取消蚂蚁借呗，我要撤回]的相似度为： 0.8118092
# [True][花呗临时额度多长时间消失]和[花呗临时额度有限期是多久]的相似度为： 0.9999999
# !!!
# [True][花呗逾期***天要利息吗]和[花呗逾期，罚息怎么算]的相似度为： 0.9406348
# !!!
# [False][没有银行卡怎样还款花呗]和[今天还了***块钱进去钱银行卡扣了怎么花呗里面却没有收到]的相似度为： 0.85575676
# [False][我借呗怎么用不了]和[为什么申请了借呗会不通过]的相似度为： 0.9036529
# [False][重新审核花呗要多久]和[我花呗要多久才能重新启用]的相似度为： 0.7844493
# [True][蚂蚁借呗可以分多少期]和[我的借呗可以分***期吗]的相似度为： 0.8797455
# !!!
# [False][我的借呗额度是用完了]和[可是借呗额度不够]的相似度为： 0.9999879
# [True][为什么没有，蚂蚁借呗]和[里面没有蚂蚁借唄了]的相似度为： 0.8385321
# !!!
# [False][花呗是否会自动扣款余额宝]和[我借呗借的钱余额宝会自己扣吗]的相似度为： 0.9416059
# [False][关于花呗收款额度]和[收款禁止使用花呗]的相似度为： 0.9999998
# [False][为什你花呗里边的手机号跟我注册的手机号不一样]和[为啥我新注册的手机号，不能用蚂蚁花呗]的相似度为： 0.90399575
# [True][开通花呗收款，出现您的资质不符合开通条件，还有什么办法]和[我的支付宝账户被告知不符合条件开通花呗收钱]的相似度为： 0.9455249
# !!!
# [False][为什么我借不了借呗]和[蚂蚁借呗为啥到不了账]的相似度为： 0.89095247
# [True][我在华为商城买手机，说我的花呗分期余额不足]和[提示花呗分期金额不足]的相似度为： 0.94156945
# !!!
# [False][花呗额度调降后能恢复吗]和[怎么样可以恢复花呗额度使用]的相似度为： 0.8597529
# [False][帮我看看我是否开通了花呗]和[怎麼知道我是否開通花唄了]的相似度为： 0.8300681
# [True][我订过火车票，但是没出票成功，花呗自动退款了，但是在之前我把花呗还款了，那花呗还会退钱吗]和[我想哈，我这个月花呗提前还清了，但是我在付清之后退票了，现在退的票是之前花呗付的，那这个钱到哪里去了？怎么少了]的相似度为： 0.97626317
# !!!
# [False][借呗***号借了钱，什么时候还]和[怎么还蚂蚁借呗的钱]的相似度为： 0.9494666
# [False][蚂蚁花呗无法同意授权]和[授权好友，花呗]的相似度为： 0.78300905
# [False][我为什么没有申请蚂蚁借呗的选项]和[我的借呗为什么没开]的相似度为： 0.7855396
# [False][我的蚂蚁借呗为什么开通不了]和[我不想要这个想开通借呗怎么开]的相似度为： 0.9448211
# [True][主动申请蚂蚁借呗入口在那]和[怎么样去主动申请借呗]的相似度为： 0.9526875
# !!!
# [False][银行卡丟了蚂蚁借呗怎么还款]和[打扰 蚂蚁借呗 那有借出来的还款六个月还还是怎么样的]的相似度为： 0.7735915
# [True][开通花呗不用钱要不要利息]和[开通花呗后，不使用，会产生费用吗]的相似度为： 0.97966886
# !!!
# [False][花呗可以支付餐厅点的钱吗]和[花呗可以支付医疗吗]的相似度为： 0.7735316
# [True][我用花呗买的火车票。然后改签火车票还是用花呗付款。怎么第一次的钱没退回]和[花呗买的火车票，改签了，但是没有退款]的相似度为： 0.9079379
# !!!
# [False][花呗消费为什么有短信验证码]和[借呗申请借款会有短信验证码]的相似度为： 1.0
# [True][戚用借呗赌博，能关闭他的借呗么]和[问借呗能关闭不]的相似度为： 0.77316606
# !!!
# [False][分期商品是在花呗分期还款吗]和[我不是购买的时候是花呗分期吗？为什么还是按商品全额扣款]的相似度为： 0.919541
# [False][蚂蚁借呗跟网商贷什么关系]和[蚂蚁借呗跟网商贷是冲突的吗]的相似度为： 0.99999857
# [False][蚂蚁借呗能借钱?吗]和[蚂蚁借呗能申请延期还款吗]的相似度为： 0.9656705
# [True][花呗提前还清，有利息吗]和[花呗分期后提前还款需要还利息么]的相似度为： 0.9656104
# !!!
# [False][怎么花呗不能开通]和[蚂蚁花呗应该怎么样开通，肯定要开通蚂蚁花呗]的相似度为： 0.9526317
# [True][花呗和支付宝不是一个号码怎么改成一样的]和[怎么把花呗从这个支付宝换到另外一个支付宝]的相似度为： 0.7736707
# !!!
# [True][我的花呗为什么不能用了]和[为什么蚂蚁花呗不管使用]的相似度为： 0.9140089
# !!!
# [False][花呗自动扣款还款失败]和[余额有钱花呗还自动扣款失败]的相似度为： 0.85206014
# [True][怎么不可以用花呗额度]和[有花呗剩余额度，却用不了]的相似度为： 0.98016924
# !!!
# [True][a账户已经关闭花呗，b账户怎样才能开通花呗]和[我有两个淘宝账号，另外一个把花呗关闭了，另外一个怎么开通]的相似度为： 0.9703608
# !!!
# [False][借呗借了。为什么钱没到]和[借呗怎么确定不了借钱]的相似度为： 0.94948936
# [True][我的花呗花在哪里了我不知道]和[我的花呗都花在哪里，怎么查]的相似度为： 0.9417523
# !!!
# [False][借呗还款显示订单处理中]和[借呗还款余额清单]的相似度为： 0.96619225
# [False][花呗红包多少钱]和[花呗收钱能抵扣红包吗]的相似度为： 0.9159112
# [False][淘宝上花呗支付的要怎么还款]和[在你妈的感觉真的说，我淘宝花呗怎么还款呀]的相似度为： 0.9468273
# [True][在蚂蚁借呗里借的钱能最低还款吗]和[借呗可以手动还最低还款额吗]的相似度为： 0.9521792
# !!!
# [False][为什么我没有借呗额度]和[为什么没有借呗]的相似度为： 0.9090432
# [True][花呗付款要收手续费]和[用花呗购物还扣手续费吗]的相似度为： 0.96709514
# !!!
# [False][现在能申请花呗临时额度吗]和[花呗的临时额度还款有期限吗]的相似度为： 0.8946445
# [False][花呗信用卡收款服务是什么意思]和[花呗和信用卡收款码图片]的相似度为： 0.9999907
# [False][如何设置花呗账号]和[花呗怎么设置]的相似度为： 0.96566594
# [True][已经关闭了花呗，为什么新的帐号申请还是显示另外一个帐号在登录]和[另一个账户已经关闭花呗，这个账户为什么还显示用另一个账户使用花呗]的相似度为： 0.95288104
# !!!
# [True][申请开通花呗信用卡收款]和[如何开通支持花呗和信用卡付款的收款二维码]的相似度为： 0.9999845
# !!!
# [True][我的蚂蚁借呗是不是不可以用了]和[怎么用不了蚂蚁借呗]的相似度为： 0.9662001
# !!!
# [False][蚂蚁借呗提前还清不用了会扣什么利息嘛]和[蚂蚁借呗提前还款利息还是一样的跟分期一样吗]的相似度为： 0.9822835
# [False][蚂蚁花呗咋更换手机号]和[使用花呗提示我更换号码]的相似度为： 0.81343603
# [False][花呗钱不用就不用还款]和[用花呗付款支付宝里有钱是不是就不用还花呗钱了]的相似度为： 0.848452
# [True][收款码开通蚂蚁花呗收款]和[二维码收款花呗]的相似度为： 0.95103145
# !!!
# [True][借呗还款是几点]和[蚂蚁借呗还款日当天***点是凌晨还是中午]的相似度为： 0.9230618
# !!!
# [True][我的花呗逾期还款了，还可以使用吗]和[我的花呗逾期还能在打开使用吗]的相似度为： 0.92972976
# !!!
# [False][看一下花呗可以借多少]和[借呗一期可以借几次]的相似度为： 0.9090582
# [True][花呗分期后可用额度是多少]和[花呗分期后还有多少额度]的相似度为： 0.9417107
# !!!
# [False][借呗额度都有多少]和[我想查借呗额度]的相似度为： 0.96617275
# [False][花呗临时额度可以查的吗]和[花呗提额哪里]的相似度为： 0.91638416
# [True][蚂蚁借呗可按年还吗]和[蚂蚁借呗还款的相关规则]的相似度为： 0.9592456
# !!!
# [True][花呗分期需要多少钱，才能分期]和[花呗达到多少额度才能分期]的相似度为： 0.96570295
# !!!
# [False][花呗怎么设置单独的支付密码]和[花呗，***以下怎么设置支付密码]的相似度为： 0.94067836
# [False][花呗上的钱还不上怎么办]和[我花呗今天还一点还还清怎么用不了]的相似度为： 0.96984076
# [False][花呗出现系统繁忙]和[为什么每次进花呗显示系统繁忙]的相似度为： 0.8006638
# [False][我是商家！我要开通花呗分期]和[我已经开通商家花呗收钱，怎么没有用]的相似度为： 0.9135742
# [False][之前我选择退款退货了，为什么花呗有***元的账单]和[我之前确认收货，后面又申请退货，花呗又怎么退，会出账吗]的相似度为： 0.92844653
# [False][蚂蚁借呗逾期后还款还能再借吗]和[借呗还了以后还可以再借吗]的相似度为： 0.97542036
# [True][花呗收款二维码怎么搞的]和[能不能做个花呗二维码商家收钱的]的相似度为： 0.76310647
# !!!
# [False][我不花花呗的钱是不是不用还]和[如果我不用花呗是不是就不会用花呗的钱]的相似度为： 0.93869054
# [False][花呗收款 有限制吗]和[花呗收款什么会有限额]的相似度为： 0.8944564
# [False][蚂蚁借呗在还款日当天几点前还款不算逾期]和[蚂蚁借呗当天还就不算逾期吧]的相似度为： 0.92156655
# [False][为什么我开通不了信用卡跟花呗收款]和[申请了花呗和信用卡收款怎么还不能收款]的相似度为： 0.9413495
# [False][可不可以把花呗换到另外一个支付宝]和[花呗贷款可以转到支付宝账号里面吗]的相似度为： 0.91884875
# [False][***月花呗的钱我没有钱还了]和[还是下个月可以花呗按最低还款]的相似度为： 0.89905953
# [False][借蚂蚁借呗钱要绑定银行卡吗]和[没绑定银行卡可以花呗吗]的相似度为： 0.8911058
# [True][交电费怎用不了花贝]和[花呗交电费怎么没办法]的相似度为： 0.9406417
# !!!
# [False][想取消花呗，怎么做]和[收钱怎么取消花呗服务费]的相似度为： 0.83852756
# [True][花呗负数有什么影响]和[我的花呗透支了***元有什么影响]的相似度为： 0.94054586
# !!!
# [False][花呗到期可以分期还款吗]和[蚂蚁花呗逾期了可以分期吗]的相似度为： 0.9750931
# [False][我花呗退款在哪]和[花呗还款后，退款会到哪里]的相似度为： 0.9192411
# [True][借呗还完一期后额度为什么不会恢复]和[我的借呗忘还了，但是已经还了，什么时候能恢复额度]的相似度为： 0.98101175
# !!!
# [False][怎样解除花呗邀请朋友还款]和[我刚刚点了花呗帮忙还款的]的相似度为： 0.89120454
# [False][为什么没有临时花呗额度资格]和[我的花呗临时怎么没了]的相似度为： 0.85966825
# [False][我的花呗什么时候才可以再次开通]和[我的需要多久才能开通花呗]的相似度为： 0.8931278
# [False][花呗是只要借款就有利息么]和[花呗真的是零利息吗]的相似度为： 0.9510513
# [False][花呗怎么不能扫描二维码]和[花呗不能扫描二维码支付]的相似度为： 1.0
# [False][借呗第一个月还款日是多久]和[蚂蚁借呗多久需要还]的相似度为： 0.99998057
# [False][花呗分期免息有手续费么]和[花呗分期利息要多少]的相似度为： 0.96568
# [True][***号用的花呗几时还款]和[我今天用花呗消费的什么时候还款]的相似度为： 0.9129813
# !!!
# [False][是不是必须得绑定银行卡才能够开通蚂蚁借呗]和[不绑定银行卡不能用w花呗吗]的相似度为： 0.9162538
# [False][花呗临时额度多久可以转正]和[可以吧把花呗的额度转哈吗]的相似度为： 0.95923597
# [True][花呗只可以购物]和[花呗只能购物用吗]的相似度为： 0.95102865
# !!!
# [False][我的借呗能提额度多少]和[借呗最高额度多少钱]的相似度为： 0.91605425
# [False][滴滴打车免密支付为何不能从花呗扣款]和[花呗能打滴滴车吗]的相似度为： 0.9161148
# [False][怎么充值超***，花呗用不了]和[花呗怎么个用法]的相似度为： 0.7841534
# [False][我花呗没有逾期，怎么我又逾期了]和[如何查看花呗逾期了没有]的相似度为： 0.960522
# [False][花呗授权被取消]和[取消此借呗授权]的相似度为： 0.8414725
# [False][花呗签约啥意思]和[花呗末还清什么意思]的相似度为： 0.85527796
# [True][借呗和网商贷并存吗]和[有网商贷 是不是不可以有借呗]的相似度为： 0.91934466
# !!!
# [False][我另一个实名的支付宝账号怎么不能开通花呗]和[我另外一个支付宝账户花呗已关闭，这个支付宝账号为什么还不能开通]的相似度为： 0.96175134
# [True][为什么花呗都不能用了]和[怎么不可以花呗]的相似度为： 0.99997264
# !!!
# [False][蚂蚁借呗通过什么方式还款]和[蚂蚁借呗未还清 但需要重新申请开通是什么意思]的相似度为： 0.9750331
# [True][花呗额度可以转给好友么]和[花呗的额度可以转给别人吗]的相似度为： 0.91402566
# !!!
# [False][我的额度还有那么多却用不了 拿这花呗没什么用]和[为什么我的借呗被关了]的相似度为： 0.9215269
# [False][借呗，什么时候可以恢复额度]和[怎样才能恢复借呗额度]的相似度为： 0.9339201
# [True][花呗到底是***号还是***号还款]和[蚂蚁花呗最晚还款日是几号]的相似度为： 0.96253395
# !!!
# [False][花呗可以给我在提身***额度吗]和[怎么提升花呗额度]的相似度为： 0.91159606
# [True][借呗可以两天内还款吗]和[蚂蚁借呗借完以后什么时候可以还款]的相似度为： 0.9303077
# !!!
# [True][蚂蚁借呗有额度，怎么借不了款]和[我的蚂蚁借呗怎么不能用]的相似度为： 0.9213041
# !!!
# [True][蚂蚁借呗点击后提示存在风险如何去除]和[借呗提示安全风险]的相似度为： 0.9186381
# !!!
# [True][为啥借呗还款受到金额限制]和[蚂蚁借呗还款金额受限制是什么意思]的相似度为： 0.94182694
# !!!
# [False][花呗账单分期 费率]和[花呗分期免手续费卷]的相似度为： 0.9606106
# [False][电脑上的蚂蚁借呗]和[我想查一下我蚂蚁借呗]的相似度为： 0.965703
# [True][我的蚂蚁借呗怎么提]和[借呗怎么才会提额]的相似度为： 0.92137253
# !!!
# [True][我的蚂蚁借呗 为什么额度降了]和[为何我蚂蚁借呗额度降低了]的相似度为： 0.9417394
# !!!
# [False][我的花呗用不到，充话费用不到]和[干嘛花呗不可以冲不到话费的]的相似度为： 0.95278734
# [False][花呗逾期，还了可以恢复吗]和[花呗逾期后还清了可以在使用吗]的相似度为： 0.94066584
# [True][花呗刷脸不能通过]和[花呗扫脸为什么不行]的相似度为： 0.9649507
# !!!
# [True][用花呗可以买火车票吗]和[***火车票可以用花呗购买吗]的相似度为： 0.9593022
# !!!
# [False][这个月的花呗我还了 怎么还显示应还]和[我这个花呗还没分斯吧]的相似度为： 0.8799088
# [True][我的花呗用不了的]和[我的花呗怎么用不了，麻烦您跟我看看]的相似度为： 0.8593838
# !!!
# [False][是帮我支付的运费吗]和[我还的全是九月份消费帐单]的相似度为： 0.85196984
# [False][我的花呗***号到期，我***号还可以吗]和[我这花呗还款已经上次就是已经还到***号了，已经全还完了，为什么就出来***的]的相似度为： 0.89881074
# [True][解除另外一个手机绑定的花呗]和[花呗解绑手机]的相似度为： 0.85540223
# !!!
# [False][芝麻分和花呗额度有关系么]和[芝麻分和花呗什么关系]的相似度为： 0.99999213
# [False][花呗还款，还错了，能取消吗]和[买的东西，产生了退货，下月还还花呗吗？能把花呗的这个订单取消了吗]的相似度为： 0.94237214
# [False][借呗逾期一天会影响以后使用吗]和[蚂蚁借呗逾期一天，对信用影响大不]的相似度为： 0.9338527
# [True][蚂蚁借呗不是有***个月的吗]和[我的蚂蚁借呗怎么只有***个月这么一个期限]的相似度为： 0.6427871
# !!!
# [False][花呗怎样修改手机号被另一个手机号注册了]和[我的花呗被另一个手机注册]的相似度为： 0.9295672
# [False][花呗和实际支出不符]和[花呗金额和淘宝商品金额不符]的相似度为： 0.9638945
# [False][花呗透支多少可分期付款]和[***多积分拥有多少花呗]的相似度为： 0.8713995
# [False][是不是蚂蚁花呗用多了，就不能用蚂蚁借呗]和[能帮我查一下我小孩的借呗，跟花呗用了多少吗]的相似度为： 0.9514046
# [False][我的花呗需要调的]和[我的花呗额度可以上调吗]的相似度为： 0.9999763
# [True][芝麻借呗已授权为什么用不了]和[蚂蚁借呗已授权怎么还是用不了]的相似度为： 0.82717186
# !!!
# [True][进花呗以后，说系统繁忙]和[为什么我的花呗进去是系统繁忙]的相似度为： 0.96398723
# !!!
# [False][借呗一千块钱利息是多少]和[借呗借款***.块，钱没到，利息收了]的相似度为： 0.9309119
# [True][花呗分期，提前还清，还会收手续费吗]和[花呗分期提前还清，手续费计算]的相似度为： 0.97449785
# !!!
# [False][蚂蚁借呗的每月等额是每个月还多少]和[蚂蚁借呗最多几个月还清]的相似度为： 0.94958824
# [False][我去年***月是不是花呗里面都还清了]和[我什么时候用了花呗，我怎么不知道]的相似度为： 0.9362231
# [True][花呗可以提供结清证明吗]和[花呗开不了结清证明吗]的相似度为： 0.9801917
# !!!
# [True][借呗什么时候，还款]和[借呗是多久还款]的相似度为： 0.9282752
# !!!
# [False][芝麻信用到多少可以恢复使用蚂蚁花呗]和[花呗和芝麻信用相关]的相似度为： 0.8417422
# [False][怎么删除蚂蚁借呗的]和[怎么把借呗给我删掉了]的相似度为： 0.9193058
# [True][什么样的产品是带有花呗标示的]和[如何看是否是带有花呗标识的商品]的相似度为： 0.9468159
# !!!
# [True][花呗分期后，还是不能还]和[花呗分期不能还]的相似度为： 0.9282596
# !!!
# [True][现在怎么没有蚂蚁借呗了]和[我为什么蚂蚁借呗不见了]的相似度为： 0.9657103
# !!!
# [True][借呗这个要怎么用才能用]和[借呗的钱怎么借]的相似度为： 0.9139998
# !!!
# [False][花呗的额度不够能分期付款吗]和[分期付款 花呗额度不够怎么办]的相似度为： 0.91613084
# [True][借呗是分期的，提前还清款项]和[借呗分期后能提前还完]的相似度为： 0.9649989
# !!!
# [False][借呗怎么没有十二个月分期]和[借呗最长分期，不是十二个月吗]的相似度为： 0.965751
# [True][花呗可不可以推迟还债]和[现在花呗还不了，能延迟吗]的相似度为： 0.999992
# !!!
# [True][怎么回事借呗怎么老是不让我用]和[我的借呗怎么还用不成，怎么才可以用]的相似度为： 0.9412418
# !!!
# [False][本月花呗消费，何时还款]和[花呗当月还款之后再用是什么时候还]的相似度为： 0.9648577
# [True][怎么可以主动提高借呗额度]和[怎么有利与提升蚂蚁借呗额度]的相似度为： 0.9527353
# !!!
# [False][花呗怎么还用不了]和[为什么我的蚂蚁花呗用不了了]的相似度为： 0.95090514
# [True][为啥会暂无借呗服务]和[借呗怎么老是暂无]的相似度为： 0.95914686
# !!!
# [True][无法使用花呗购物]和[在永和大王无法用花呗]的相似度为： 0.96493316
# !!!
# [False][花呗可以付费滴滴吗]和[花呗可以用在饿了么]的相似度为： 0.92831236
# [False][逾期一次借呗还能借款吗]和[我的借呗关了还能再开吗]的相似度为： 0.7736987
# [True][为什么交易已退款至花呗仍有手续费]和[我的花呗退款了为什么会要求我还手续费]的相似度为： 0.9657438
# !!!
# [True][呗 花呗最高可透支多少]和[花呗最多能调到多少]的相似度为： 0.951035
# !!!
# [True][为什么借呗没有额度了]和[我的蚂蚁借呗怎么没有额度]的相似度为： 0.94150954
# !!!
# [True][花呗用这么久了没涨过]和[我怎么用了这么久花呗 怎么额度一直是***]的相似度为： 0.81177694
# !!!
# [False][刷脸服务影响开通花呗吗]和[我的账号 怎么无法开通花呗]的相似度为： 0.9417126
# [False][逾期之后花呗就不能用了么]和[我还花呗怎么用不了了呀]的相似度为： 0.87985843
# [False][怎么我的借呗，进去不了啦]和[为什么我借呗的钱还进去刷不出来]的相似度为： 0.96055037
# [False][花呗分期提前全付清，为啥还提示要还]和[花呗分期还没到期能提前还款吗]的相似度为： 0.96331525
# [True][蚂蚁借呗怎么不好开通了]和[借呗怎么还没开通]的相似度为： 0.9417069
# !!!
# [False][删除花呗收货地址]和[花呗购物后怎么改写收货地址]的相似度为： 0.8553251
# [False][花呗退款后是怎么抵消的]和[我花呗还款多了怎么退款]的相似度为： 0.8597401
# [False][蚂蚁借呗不逾期会影响信誉度吗]和[借呗逾期一个月会不会影响使用]的相似度为： 0.9661843
# [False][之前借呗可以借***个月，为什么现在只有***个月了]和[为什么借呗只能借六个月]的相似度为： 0.9116319
# [False][花呗可以在 饿了么 上面用吗]和[可以用花呗去加油吗]的相似度为： 0.91925037
# [False][花呗自动还款的费用可以退还吗]和[花呗自动还款还有手续费吗]的相似度为： 0.9214785
# [False][花呗到期自动还款多收费吗]和[花呗自动还款还扣手续费了]的相似度为： 0.9919723
# [False][花呗已分期，其他交易还能分期吗]和[我不想花呗分期了，能直接全款吗]的相似度为： 0.9671281
# [False][花呗还款后退款]和[花呗支付后退款]的相似度为： 0.9999999
# [False][为什么我的花呗不支持当前交易]和[为什么我的账户不支持vivo的专属花呗]的相似度为： 0.9038388
# [False][我是用花呗充话费的，这退不了吗]和[花呗话费充值错了钱能不能退还给我]的相似度为： 0.9658437
# [False][借呗的钱提错银行卡]和[借呗提错了银行卡]的相似度为： 0.9193034
# [True][开通花呗为什么无法识别脸]和[刷脸识别花呗 开通 可是刷脸 不可以在刷脸]的相似度为： 0.8180008
# !!!
# [True][已借呗电话]和[芝麻借呗客服电话]的相似度为： 0.8412478
# !!!
# [False][花呗不能扫码支付么]和[线下支付用花呗不能超过***是什么意思]的相似度为： 0.6802431
# [False][花呗额度不准]和[花呗额度定金]的相似度为： 1.0
# [False][我实体店铺怎么开通花呗收款]和[客人来我店里用花呗]的相似度为： 0.95104176
# [False][花呗哪里领临时额度]和[花呗双***领取的临时额度，还款之后额度还有吗]的相似度为： 0.9516907
# [True][为什么我的淘宝有花呗 支付宝上却没有]和[为什么淘宝可以用花呗，支付宝没有]的相似度为： 0.94487023
# !!!
# [False][商户花呗收款]和[商户花呗收钱额度]的相似度为： 0.8949478
# [True][花呗不安时还会怎么样]和[我不用支付宝了，花呗的款不还会怎么样]的相似度为： 0.9639182
# !!!
# [False][我的花呗账号密码忘了怎么办]和[我的花呗帐号忘记了怎么办]的相似度为： 0.95925695
# [False][花呗自动还款怎么设置]和[花呗到期能自动还款吗]的相似度为： 0.95922
# [False][旧账号不用了花呗没还完怎么办]和[怎么别的平台没还钱你们平台还不给用花呗了嘛]的相似度为： 0.9496987
# [False][花呗还款超过一天有影响吗]和[花呗当天还，当天用对芝麻信用有影响吗]的相似度为： 0.9661454
# [False][营业执照法人和支付宝同一人，为什么还是开通不了花呗收款]和[有营业执照为什么开通不了花呗收款]的相似度为： 0.9362035
# [True][怎么把别的账户花呗转到这个账户]和[一个账号上的花呗怎么可以转到另外一个账号上]的相似度为： 0.9518747
# !!!
# [False][花呗还款到账]和[花呗今天能到账]的相似度为： 0.8949425
# [False][我用花呗付款为什么花呗扣钱了，卡里也一起扣钱了]和[上期借呗自动还款，银行卡里扣了钱，余额宝里也扣了钱，怎么回事]的相似度为： 0.954329
# [False][花呗不能扫描二维码付款了]和[扫二维码强开借呗]的相似度为： 0.8136253
# [False][花呗让登录qq邮箱是什么意思]和[花呗，现实不是我的qq邮箱]的相似度为： 0.8946445
# [True][能不能开通？？借呗]和[借呗能不能开一下呀，等着用钱]的相似度为： 0.95219576
# !!!
# [True][可以提额吗 借呗]和[不要网商贷可以提借呗的额度吗]的相似度为： 0.8584552
# !!!
# [True][借呗逾期一天，对我有没有影响]和[借呗逾期会影响个人信息吗]的相似度为： 0.89502996
# !!!
# [True][我的花呗为什么不能支付？只能在淘宝购物]和[花呗为什么只能网上买]的相似度为： 0.72853345
# !!!
# [False][借呗怎么没有了]和[为啥我借呗没有额度]的相似度为： 0.95910513
# [False][我可以用卡里面的钱转入花呗吗]和[用蚂蚁花呗额度兑换提现积分可以转卡吗]的相似度为： 0.9283197
# [False][为什么借呗额度越来越低]和[我要调低借呗额度]的相似度为： 0.92826915
# [False][花呗收钱收取手续费]和[花呗服务费]的相似度为： 0.91620874
# [False][我的借呗为啥开不同]和[我的借呗也不能用，能开通嗎]的相似度为： 0.8298906
# [False][能帮我提升借呗额度]和[借呗多长时间能提额]的相似度为： 0.9801801
# [False][花呗冻结怎么激活]和[我的花呗怎么给我冻结了]的相似度为： 0.8133317
# [False][摩托单车可能用花呗么]和[小蓝单车也是用花呗付的]的相似度为： 0.99999774
# [False][借呗额度想提高该怎么办]和[借呗额度挺升]的相似度为： 0.8949025
# [True][借呗逾期三四天有事嘛]和[借呗逾期一天还款会有什么影响吗]的相似度为： 0.99997115
# !!!
# [True][为什么买东西银行卡负的款，花呗还扣了]和[上淘宝买东西明明是自己付了款为什么变成花呗付款，还让我付两次款]的相似度为： 0.9454802
# !!!
# [True][此单退了，为啥欠花呗还是***多，退的钱去哪里了]和[退回来的钱不在花呗，钱退那里去了]的相似度为： 0.9433816
# !!!
# [False][为什么我的借呗不能用了]和[为什么无法开通借呗]的相似度为： 0.96493065
# [False][花呗每月多少能提额度]和[花呗借款最多多少]的相似度为： 0.7844911
# [True][蚂蚁借呗里我的校验码收不到怎么办]和[借呗怎么提现收不到验证码]的相似度为： 0.94961643
# !!!
# [True][蚂蚁借呗需要芝麻信用多少分能借]和[蚂蚁借呗开通需要多少信誉额度]的相似度为： 0.92606074
# !!!
# [True][借呗，怎么用着就没额度了]和[借呗开始有额度，借过一次之后怎么没有了]的相似度为： 0.92124003
# !!!
# [True][网商贷和借呗是一个性质不]和[借呗跟网商贷有什么不同]的相似度为： 0.99999785
# !!!
# [True][借呗***号以后借的钱几号还]和[借呗本月***号借款什么时候还钱]的相似度为： 0.89470077
# !!!
# [False][怎么没有看到花呗了]和[怎么在花呗中没看到]的相似度为： 0.9160257
# [True][花呗给我开通下]和[给我的花呗开了]的相似度为： 0.9192537
# !!!
# [False][蚂蚁借呗怎么还需要申请]和[借吧怎么申请提额]的相似度为： 0.9999767
# [False][还完款了花呗不显示]和[我的--花呗后不显示主动还款]的相似度为： 0.6925284
# [True][申请蚂蚁借呗最后手机验证码收不到是不是钱不会到账]和[借呗申请后，手机收不到验证码]的相似度为： 0.9037773
# !!!
# [False][我的转账超限额只能还信用卡不能还花呗么]和[为什么我开通了信用卡花呗付款，用花呗跟信用卡付不了]的相似度为： 0.92936844
# [False][同一个身份证认证的支付宝可以共享花呗和借呗吗]和[同个身份证下花呗能共享吗]的相似度为： 0.9140783
# [True][还可以开通花呗吗]和[我这个号可以开通花呗不]的相似度为： 0.9590999
# !!!
# [False][借呗不是可以分期一年还吗]和[借呗能不能重新分期]的相似度为： 0.90368545
# [False][充值加油卡可以使用花呗充值吗]和[用花呗充值加油卡有利息吗]的相似度为： 0.82710236
# [True][蚂蚁花呗和蚂蚁借吧什么不同]和[花呗和蚂蚁借呗有何不同]的相似度为： 0.90392137
# !!!
# [True][和关联账户解绑了还是显示花呗在账户上怎么办]和[关联账号花呗关闭了为什么还是显示]的相似度为： 0.98020536
# !!!
# [True][花呗可以在线下付款吗]和[线下花呗消费]的相似度为： 0.801156
# !!!
# [True][一般人都能开通花呗和借呗，为什么我的开通不了]和[我怎么开不了借呗，花呗]的相似度为： 0.924979
# !!!
# [False][蚂蚁借呗还款有积分吗]和[蚂蚁借呗还清了马上又有新的额度吗]的相似度为： 0.95907456
# [True][所有商家都支持花呗购买为什么我花呗不能付款]和[店家支持花呗支付，为什么我用花呗支付不了]的相似度为： 0.97503966
# !!!
# [True][这个支付宝怎么关花呗]和[不想用这个花呗，这个上面钱怎么取消]的相似度为： 0.76576823
# !!!
# [False][我的花唄也無法申請]和[我想申请用花呗]的相似度为： 0.90902036
# [False][我想更换手机号 但是我的我的花呗和借呗都还有款没还完]和[不是，我原来的账号有花呗，还有几天就到期了，我现在登陆的不是我的账号]的相似度为： 0.9587396
# [True][我花呗咋点不到同意授权]和[花呗授权怎么不行]的相似度为： 0.81823325
# !!!
# [True][建设银行的银行卡支持花呗吗]和[蚂蚁借呗支持建设银行卡还款吗]的相似度为： 0.95225704
# !!!
# [False][花呗领取了零食额度]和[帮我吧花呗临时额度取消]的相似度为： 0.9605887
# [False][我的借呗没有扣款]和[借呗什么没有自动扣款]的相似度为： 0.8519213
# [False][客户为什么用花呗支付不了款]和[申请信用卡和花呗收钱码付款为什么显示我的账户不支持]的相似度为： 0.9656219
# [True][花呗住酒店在哪儿]和[花呗住宾馆]的相似度为： 0.9162471
# !!!
# [False][花呗账号绑定的号码没用了，怎么办]和[花呗! 我点开了，但是我没用，怎么办]的相似度为： 0.9472216
# [False][今天花呗提前还款没看到]和[怎么没看到有花呗分期]的相似度为： 0.9999975
# [False][为什么生活缴费不能用花呗支付]和[显示此交易不支持花呗支付]的相似度为： 0.96499217
# [False][花呗交易记录清除]和[这个，蚂蚁花呗交易记录怎么删除]的相似度为： 0.9214487
# [True][花呗的最低还款是什么意思]和[花呗帐单最低还钱是什么]的相似度为： 0.9640356
# !!!
# [True][花呗冻结，什么时候可以使用]和[我花呗被冻结了，什么时候能用]的相似度为： 0.95921177
# !!!
# [True][花呗免密支付 设置]和[花呗怎么开免密]的相似度为： 0.7735048
# !!!
# [True][为什么封了我借呗]和[你们支付宝，为什么把我的蚂蚁借呗，给停了]的相似度为： 0.97576004
# !!!
# [False][花呗初始信用额度是多少]和[花呗可以最高支付多少额度]的相似度为： 0.9282777
# [False][可是我已经验证完成了…花呗还是显示身份验证失败]和[为什么我的蚂蚁借呗拍了身份证照也还显示去完善]的相似度为： 0.9722947
# [False][花呗服务费是收取卖家的]和[花呗支付服务费是什么]的相似度为： 0.9657681
# [True][退款优先退回您的花呗账单， 若您账单已还清，则退回您的账户余额，点击【余额】—【账户余额】，查询账户收支明细即可]和[如果您是在交易确认收货后发起售后维权，退款优先退回您的花呗账单，  若您账单还款时已还清则退回您的账户余额，点击【余额】—【账户余额】，查询账户收支明细即可。  若]的相似度为： 0.9641657
# !!!
# [False][蚂蚁借呗可以按每一笔还吗]和[蚂蚁借呗借款可以直接提到银行卡吗]的相似度为： 0.9513794
# [False][从哪儿看我的借呗记录]和[借呗功能在哪儿]的相似度为： 0.9090432
# [False][怎么样借呗能提额]和[借呗为什么这么久不提额]的相似度为： 0.9414966
# [False][我还缺什么能开通花呗]和[开通花呗为什么要刷脸]的相似度为： 0.81832874
# [True][蚂蚁借呗怎么没有信誉额度了]和[借呗额度怎么没了]的相似度为： 0.87118036
# !!!
# [True][花呗还款日期能不能改***]和[花呗的还款日期可以修改的吗]的相似度为： 0.914015
# !!!
# [False][我的花呗为什么超过***，就支付不了了？是需要设置什么吗]和[意思是说我支付宝永远用不了花呗]的相似度为： 0.94763386
# [True][蚂蚁借呗怎么不可以分期***个月]和[蚂蚁借呗怎么没有***个月的分期了]的相似度为： 0.9999993
# !!!
# [False][我的借呗款怎么到现在都没到账]和[我在蚂蚁借呗，借的钱怎么还没到账]的相似度为： 0.90521836
# [True][找不到花呗图标怎么办]和[登陆我的找不到花呗]的相似度为： 0.9500287
# !!!
# [False][花呗分期***期免息券]和[花呗分期免息券活动什么时候开始]的相似度为： 0.99998677
# [False][收钱码，收花呗]和[支付宝收钱码可以收花呗里钱吗]的相似度为： 0.8939202
# [False][蚂蚁花呗买东西退款的钱怎么两天都没到帐]和[昨晚退回到花呗的钱怎么没信息？是不是还没到账]的相似度为： 0.91931885
# [False][还款后如何解除花呗]和[如何取消花呗账单好友代还]的相似度为： 0.9187684
# [False][收款码，不能花呗付款]和[我的收钱码为什么不能花呗付款]的相似度为： 0.9999819
# [False][借呗借款期限为什么只有六个月]和[借呗期限没有***个月了吗]的相似度为： 0.91925395
# [False][卖家退的款怎么在花呗里]和[卖家退回了花呗]的相似度为： 0.8711162
# [False][网商贷已经关闭了]和[我想把网商银行关了]的相似度为： 0.9283042
# [False][花呗还款日期可以帮我推后几天吗]和[花呗的还款日期可以换吗]的相似度为： 0.913951
# [False][关联账户取消后，可以开通花呗吗]和[账户能开通花呗吗]的相似度为： 0.9589774
# [True][蚂蚁借呗要达到多少分]和[蚂蚁积分到多少才能使用蚂蚁借呗]的相似度为： 0.88170075
# !!!
# [True][此押金没有退款到花呗，app 显示已退款会]和[第三方显示已经退款，但花呗还没有收到钱]的相似度为： 0.94683015
# !!!
# [True][开通密付，可以用花呗付款么]和[密度会用花呗支付吗]的相似度为： 0.9999717
# !!!
# [True][借呗可以修改还款期数吗]和[可以修改蚂蚁借呗借款期限吗，可以由***个月改到***个月吗]的相似度为： 0.92905855
# !!!
# [False][***月份花呗境外返现]和[花呗返现资格]的相似度为： 0.8593987
# [True][我花呗还款日能修改一下吗]和[怎么改蚂蚁花呗每月的还款日期]的相似度为： 0.7984907
# !!!
# [True][花呗显示是每月九号还款，十号还款有影响吗]和[花呗晚还了一个小时，忙忘记了有影响吗]的相似度为： 0.94680095
# !!!
# [True][可以提升蚂蚁花呗的临时额度嘛]和[花呗如何提升额度]的相似度为： 0.9187121
# !!!
# [False][还了花呗，马上又可以用嘛]和[我多些可以用花呗]的相似度为： 0.9657497
# [True][每个月***号花呗还款]和[我的花呗每月几曰还款]的相似度为： 0.9494903
# !!!
# [True][我为什么没有蚂蚁借呗功能]和[我支付宝里怎么没有蚂蚁借呗]的相似度为： 0.96575016
# !!!
# [True][蚂蚁花呗最迟***几点还]和[蚂蚁花呗最迟是什么时候还款]的相似度为： 0.9999985
# !!!
# [False][是不是不可以使用支付宝花呗]和[可以使用花呗的二]的相似度为： 0.91334236
# [False][我的花呗可以恢复使用了吗]和[我的支付宝怎么不能用花呗了]的相似度为： 0.87144476
# [False][我的花呗，为什么会有多的金额]和[押金退了为什么蚂蚁花呗还有账单]的相似度为： 0.8415322
# [False][我的支付宝为什么没有借呗，也没有蚂蚁借呗]和[有些不用支付宝都有借呗，我长年在用支付宝也没有借呗]的相似度为： 0.9518361
# [True][借呗以前可以***期现在为什么不可以]和[蚂蚁借呗为什么不能分***期]的相似度为： 0.6806505
# !!!
# [False][我明明用的余额。为什么是花呗]和[花呗为什么在我不知情的情况下会被刷]的相似度为： 0.91124165
# [False][花呗分期付款退款时间]和[花呗还了分期账单，再花花呗的，那花的要几时还款]的相似度为： 0.95911276
# [False][银行卡里没钱可以花呗的吗]和[还款中，银行卡里面钱已经扣了，但花呗的需还款没有变少]的相似度为： 0.8179336
# [False][怎样知道自己的花呗额度]和[花呗信用额度怎么清***]的相似度为： 0.9297001
# [False][借呗开通了 页面为什么不显示]和[蚂蚁借呗还了怎么不显示额度了]的相似度为： 0.9324111
# [False][你能给我一个关闭以后的借呗图片我看一下吗]和[关闭借呗窗口]的相似度为： 0.8177581
# [False][花呗的额度冻结怎么回复]和[怎么样冻结蚂蚁花呗]的相似度为： 0.9193013
# [False][如何查询花呗用到哪里去了]和[帮我查下***多蚂蚁花呗兜还哪里去了]的相似度为： 0.90611774
# [False][一个身份证只能开通一次 借呗吗]和[同一个身份能开几个借呗]的相似度为： 0.909055
# [True][为什么我的花呗还不提额]和[为什么我的花呗透支一直不涨]的相似度为： 0.9415364
# !!!
# [False][花呗支付时没有密码 想设置密码]和[从那里设置花呗密码]的相似度为： 0.87122774
# [True][我的花呗余额还有***多为什么支付一百多的东西显示余额不足]和[花呗帐单有一笔***元支出，已在昨天还的帐单里面。为啥可用余额还不足***元]的相似度为： 0.87844145
# !!!
# [False][怎样取消花呗消费的短信提醒]和[蚂蚁花呗消费金额短信提醒]的相似度为： 0.92599666
# [False][花呗额度一直不提高]和[花呗额度可以提高吗]的相似度为： 0.9801801
# [True][借呗借到支付宝还可以提现吗]和[蚂蚁借呗有借款可以提现吗]的相似度为： 0.76610565
# !!!
# [True][水电费花呗支付]和[花呗缴纳水电]的相似度为： 0.8134219
# !!!
# [True][不能用花呗了]和[为什么我的花呗不能]的相似度为： 0.9192916
# !!!
# [False][蚂蚁借呗为什么管不了]和[借呗有余额怎么借不出来了]的相似度为： 0.7828814
# [True][我的蚂蚁借呗为什么就开通不了]和[我蚂蚁借呗咋弄不开]的相似度为： 0.78727365
# !!!
# [False][我的蚂蚁借呗怎么没有点我功能]和[为什么我支付宝里没有蚂蚁借呗]的相似度为： 0.9213785
# [False][为什么点开花呗，要登录邮箱]和[花呗邮箱登录不了]的相似度为： 0.92120796
# [False][点击开通花呗收款页面的时候怎么提示无法开通本功能]和[我怎样能开通蚂蚁花呗收款]的相似度为： 0.9670845
# [False][花呗分期后 不能按时还款怎么办]和[花呗的钱分期后不能还全部钱吗]的相似度为： 0.9522135
# [True][这个支付宝不能使用借呗]和[我这个支付宝借呗怎么没有额度]的相似度为： 0.69271183
# !!!
# [True][用花呗支付有算利息吗]和[花呗有没有利息***]的相似度为： 0.8798411
# !!!
# [False][我花呗逾期一天会对信用产生影响吗]和[迟一天影响大不大，会不会无法使用花呗]的相似度为： 0.90910363
# [True][蚂蚁花呗多少估评一次]和[蚂蚁花呗多久审核一次]的相似度为： 0.766225
# !!!
# [False][借呗的额度和什么有关]和[蚂蚁借呗额度什么时候能提升到以前的额度]的相似度为： 0.8895701
# [True][花呗退款成功但是待还款没有变化]和[退完款 花呗还款怎么没变化]的相似度为： 0.8133019
# !!!
# [False][我花呗上个月还了最低还款]和[用了之后是不是还花呗钱]的相似度为： 0.9587026
# [True][淘宝花呗分期付款怎么用]和[花呗分期商品怎么用]的相似度为： 0.8133846
# !!!
# [True][网商贷怎样变为蚂蚁借呗]和[如何把网商贷转换为借呗]的相似度为： 0.8950374
# !!!
# [False][银泰包可以花呗付款吗]和[花呗可以组合付款么]的相似度为： 0.9999974
# [False][我用微信里的钱还花吧怎么还]和[我用微信零钱还花呗怎么还不了]的相似度为： 0.9657509
# [False][花呗分期后一次性还清还需支付利息吗]和[花呗分期后还了一期，然后剩余一次性还清要还利息吗]的相似度为： 0.94682217
# [True][怎么把花呗提前全款还清]和[花呗怎么提前还清所有款项]的相似度为： 0.9467884
# !!!
# [False][商家要不要先开通花呗]和[怎么辨别商家有没有开通花呗]的相似度为： 0.9415057
# [True][花呗还款我怎么还没有到帐]和[花呗还款几时到帐]的相似度为： 0.9786279
# !!!
# [True][为什么蚂蚁借呗不出来]和[为什么我的蚂蚁借呗无法借款了那]的相似度为： 0.85905164
# !!!
# [False][为什么我的借呗还不升额度]和[申请提升借呗的额度]的相似度为： 0.9414996
# [False][花呗分期还款手续费多少]和[花呗分期还款的利息怎么算的]的相似度为： 0.9999938
# [True][取消找好友还花呗]和[找朋友帮还花呗这个刚生成能取消吗]的相似度为： 0.96387494
# !!!
# [False][借呗还款日当天 不能再借款吗]和[蚂蚁借呗要一次性还清才能再借吗]的相似度为： 0.9338485
# [False][如何知道花呗收钱开通申请是否成功]和[请帮我查查是否开通了花呗软件]的相似度为： 0.9801911
# [False][逾期花呗欠的钱没还怎么办]和[我的花呗提示我有微贷产品没有还款有逾期]的相似度为： 0.93862164
# [True][为什么花呗里还有额度 却不支持付款]和[有花呗，有可用额度，为什么不能用]的相似度为： 0.94691646
# !!!
# [True][蚂蚁借呗为什么最长期限是六个月]和[蚂蚁借呗，怎么不是借***个月，只可以借***个月而已]的相似度为： 0.93210864
# !!!
# [False][蚂蚁借呗能借款提现吗]和[可以提现到借呗吗]的相似度为： 0.85550946
# [False][为什么使用不了蚂蚁借呗]和[我信用很好，为什么借呗没有额度]的相似度为： 0.96408606
# [False][我的花呗怎么提升不了]和[蚂蚁借呗怎么提升额度]的相似度为： 0.93385476
# [True][自己怎么提升借呗额度]和[借呗怎么能快速提高额度]的相似度为： 0.9999976
# !!!
# [False][借呗分期从那里扣]和[借呗到账会分期吗]的相似度为： 0.91596806
# [False][信用度多少才可以开通花呗]和[芝麻信用分是多少可以开通花呗]的相似度为： 0.82729954
# [True][花呗能自动还款]和[我的花呗怎么自动还款了]的相似度为： 0.96704817
# !!!
# [False][做个花呗收钱码]和[花呗支付宝收款码]的相似度为： 0.80112404
# [False][蚂蚁借呗为何变成了网商贷]和[网商贷突然变成借呗的原因]的相似度为： 0.89820254
# [True][逾期之后多长时间能恢复花呗]和[花呗逾期后多会才能再用]的相似度为： 0.9213316
# !!!
# [True][我什么时候用了花呗钱]和[我什么时候用花呗了我都不知道]的相似度为： 0.91105044
# !!!
# [False][密付不能用花呗支付吗]和[密付能从花呗扣款吗]的相似度为： 0.9510257
# [False][蚂蚁借呗为什么不能借***月期]和[蚂蚁借呗怎么借不了***期]的相似度为： 0.9999972
# [True][蚂蚁花呗如果预期没还会有什么后果]和[花呗分期逾期未还有什么影响]的相似度为： 0.9657501
# !!!
# [False][一个支付宝绑定一个淘宝账户，也就是说一个人只能有***个淘宝呗]和[我自己支付宝里就有钱 但是我还是需要把钱提到卡里 然后再把钱弄到另一个帐户里 再还花贝]的相似度为： 0.94916916
# [False][另一个账户显示已开通花呗，但已经关闭了]和[其中有一个账户开通花呗。想着关了这个。开另一个账户的花呗]的相似度为： 0.9251997
# [True][花呗我还清了吗]和[我的花呗这个是不是已经还清了]的相似度为： 0.91631114
# !!!
# [True][花呗逾期后还清什么时候可以用]和[花呗逾期后还上了多久才能用]的相似度为： 0.9999989
# !!!
# [True][花呗充错了号码]和[我冲话费充错了，用的花呗支付的]的相似度为： 0.89914894
# !!!
# [True][还花呗款还重复了]和[花呗如果重复还款了怎么办]的相似度为： 0.95105803
# !!!
# [False][我的花呗不可以用么]和[问我的花呗能不能恢复使用]的相似度为： 0.81360304
# [False][使用花呗交的电费多久到帐]和[用花呗交的电费，半个月了，没到账]的相似度为： 0.97949696
# [False][我用花呗买了东西，然后那边已经退款，你这边什么时候退]和[用花呗买东西，退款会退给花呗吗]的相似度为： 0.9741268
# [False][蚂蚁借呗借***个月后还可以吗]和[借呗还款期只有***和***个月这两个吗]的相似度为： 0.95054543
# [True][我这蚂蚁借呗已经开通了，为啥现在没有了额度，没有了，啥意思]和[为何我蚂蚁借呗额度不见了]的相似度为： 0.93734807
# !!!
# [False][怎么样用花呗缴纳水电费]和[我想交电费用别人的借呗交怎么交]的相似度为： 0.92484224
# [False][手机坏了，怎样还花呗的款]和[花呗还款手机验证码怎么会发到另外一个]的相似度为： 0.965758
# [False][我的蚂蚁借呗为何没有啦]和[蚂蚁借呗我想重新开通]的相似度为： 0.89505506
# [False][怎么从新用花呗]和[怎么使用其他支付宝还逾期花呗]的相似度为： 0.90357727
# [False][同一个身份证注册的多个支付宝，花呗额度是共享的吗]和[同一身份证认证的支付宝账号借呗额度是共享的吗]的相似度为： 0.9676256
# [False][借呗图标怎么删除]和[怎么能消除蚂蚁借呗的借款记录]的相似度为： 0.9593078
# [False][为什么我的花呗没有“提前还款]和[我淘宝收货啦！我来花呗还款！倒是没有提前还款的字啦！以前收货过来就可以还款啦！现在不行]的相似度为： 0.95481926
# [False][花呗提示我用邮箱]和[花呗邮箱失效]的相似度为： 0.8949478
# [False][提现没到账，花呗账单还不了怎么办]和[这个月的花呗账单怎么还没送达]的相似度为： 0.9103105
# [False][为什么我能开通借呗但是开通不了花呗]和[为什么开通不了蚂蚁花呗 或者借呗]的相似度为： 0.9513708
# [False][开通卖家花呗怎么开通]和[卖家怎么设置花呗]的相似度为： 0.9057059
# [False][花呗分期还款的利息如何算]和[花呗最低还款后如何利息]的相似度为： 0.9999981
# [False][我问什么打不开花呗]和[打开不了花呗怎么办]的相似度为： 0.84157884
# [False][我已经用很多花呗了]和[我不会用花呗，刚刚我是不是用花呗了]的相似度为： 0.9999639
# [False][***月退回支付宝还是花呗]和[花呗还没有清呀]的相似度为： 0.94059706
# [True][我希望解冻花呗]和[我需要解冻这次***的花呗，谢谢]的相似度为： 0.8863292
# !!!
# [True][我的借呗日息怎么那么高]和[我一直用，为什么我的借呗利息还那么高]的相似度为： 0.9249039
# !!!
# [True][我可以主动申请借呗么]和[不是可以申请蚂蚁借呗么]的相似度为： 0.928301
# !!!
# [False][花呗额度***元什么意思]和[花呗额度主要看什么]的相似度为： 0.9999776
# [False][蚂蚁借呗怎么提前还款下月的]和[借呗可以提前还当月的还款]的相似度为： 0.9741694
# [False][如何取消花呗扣款]和[花呗还款是不是代扣]的相似度为： 0.9406161
# [False][我怎么让我的邮箱有花呗]和[为什么我手机我的这里显示有花呗呀]的相似度为： 0.9655808
# [False][借呗手续费是什么]和[借呗有没有手续费怎么查]的相似度为： 0.9590999
# [True][借呗太低了]和[借呗太少了]的相似度为： 0.9139802
# !!!
# [True][花呗还了不显示还款]和[为什么还了花呗的钱却还不显示]的相似度为： 0.96629965
# !!!
# [True][借呗有提醒还款功能吗]和[蚂蚁借呗有还款提醒服务吗]的相似度为： 0.97500074
# !!!
# [False][蚂蚁借呗的钱可以提现到卡里不]和[蚂蚁借呗当时还了 当时还能不能申请提现]的相似度为： 0.9307084
# [False][为什么不能开通花呗，信用卡收款]和[我今天开通了花呗和信用卡收款，怎么不能收]的相似度为： 0.93463755
# [False][花呗不能缴费电费了吗]和[蚂蚁花呗电费缴费没成功怎么不退款]的相似度为： 0.93562555
# [True][蚂蚁花呗怎么实名认证]和[怎样认证花呗]的相似度为： 0.89078355
# !!!
# [True][帮我把花呗可以透支]和[花呗是透支消费吗]的相似度为： 0.8993276
# !!!
# [True][借呗还款能恢复额度吗]和[借呗分期还后额度恢复吗]的相似度为： 0.96064067
# !!!
# [False][花呗本月已经还款了]和[还款到花呗]的相似度为： 0.7733536
# [False][花呗有密码的吗]和[借呗提额要直付密码吗]的相似度为： 0.8552134
# [False][今天有尽情花呗吗]和[双***有个尽情花呗]的相似度为： 0.96708685
# [False][我十月分的今天还的花呗]和[我的花呗今天都还了]的相似度为： 0.9605887
# [False][扫描支付用的是花呗红包不能抵扣]和[花呗红包不能门店直接抵扣吗]的相似度为： 0.96058065
# [False][这么久了我的花呗为什么还没解冻]和[我花呗冻结了还能开通吗]的相似度为： 0.7414992
# [True][我的蚂蚁借呗只可以借***个月]和[我的蚂蚁借贝怎么只可以分期六个月]的相似度为： 0.9661777
# !!!
# [False][怎么我使用花呗支付，要怎才还得款]和[但是花呗那里还要我还款]的相似度为： 0.8944666
# [False][网商贷把蚂蚁借呗给换了但是我不想用网商贷怎么才能变成蚂蚁借呗]和[我的借呗怎么升级成网商贷了]的相似度为： 0.8936999
# [False][蚂蚁借呗我分期还款了，到底哪天还，还多少，我怎么老感觉我逾期了，可是]和[蚂蚁借呗预期了，会怎么办]的相似度为： 0.9381716
# [True][这一个月的借呗还了 怎么没显示]和[借呗明明钱还了可是显示没还是怎么回事]的相似度为： 0.782847
# !!!
# [False][什么能用花呗]和[我的花呗是否能用]的相似度为： 0.9405743
# [False][我之前有过一次逾期，忘记还了，后来接着就换上了，然后花呗就不能正常使用了]和[我想把花呗重新开通一下 由于上次自身的原因到底逾期 对不起 我这次如果使用 一定提前还款]的相似度为： 0.90683067
# [True][如果我的淘宝要换绑手机号 现在的花呗能一同换到新手机号上吗]和[花呗手机号码能换吗]的相似度为： 0.7732873
# !!!
# [False][蚂蚁花呗还款日时限是几点]和[蚂蚁花呗还款日第几天为逾期]的相似度为： 0.95208555
# [False][但是我申请了退款退货了，钱款是不是自动退回给花呗]和[本月账单已经还清，可我刚申请退款了，钱退到花呗了怎么办]的相似度为： 0.9602093
# ...
# [False][提前还款不是可以选择金额？？如果我只还一部分金额是先抵扣哪个部分]和[如果这个最低还款日我没还上是不是就开始计算利息，我有钱了随时还上就可以了]的相似度为： 0.93004364
# [False][为什么不是用的花呗支付]和[付款没想用花呗的，为什么首选就是花呗]的相似度为： 0.9801868
# [False][花呗分期 额度]和[线下使用花呗分期收款]的相似度为： 0.99995303
# [False][花呗换了手机号怎么用]和[用花呗充值怎么挖宝]的相似度为： 0.87987345
# [True][用花呗买了个美团，没用退款了，钱去哪了]和[花呗买东西没发货然后花呗还了，退款的钱去那里了]的相似度为： 0.97800434
# !!!
# [True][我的花呗咋个降低了]和[为什么我的花呗额度一下降了***]的相似度为： 0.9604682
# !!!
# [False][借呗可以隔几个月后还吗]和[支付宝的朋友可以替我还借呗吗]的相似度为： 0.92460585
# [False][怎么封借呗]和[为啥封了我的借呗]的相似度为： 0.80098367
# [True][蚂蚁借呗的信用额度如何申请]和[借呗已授权，怎么申请额度]的相似度为： 0.96402067
# !!!
# [False][双***花呗免单红包在哪里领取]和[花呗双***免单集盒子途径]的相似度为： 0.9445635
# [False][刚才在蚂蚁花呗借的款，怎么取消]和[取消花呗借款申请，怎么做，不需要]的相似度为： 0.9611246
# [False][莪要开通蚂蚁借呗和花呗]和[为什么无法开花呗和借呗]的相似度为： 0.91609657
# [False][作为商家可以开通蚂蚁花呗嘛]和[商家能开通花呗嘛]的相似度为： 0.9590266
# [False][花呗在美团怎么开通]和[帮我开通花呗呀]的相似度为： 0.90902036
# [False][花呗里面的租衣服怎么进不去]和[我为什么点花呗点进去，，进不了]的相似度为： 0.8407848
# [True][收钱码，怎么不可以申请信用卡花呗付款]和[无法申请信用卡花呗收款码]的相似度为： 0.99998784
# !!!
# [False][花呗分期一次性还清会恢复额度吗]和[花呗分期了恢复额度吗]的相似度为： 0.9259411
# [False][为什么我不能使用花呗]和[为什么无法使用花呗购物]的相似度为： 0.9494903
# [True][蚂蚁借呗 提示当前操作可能存在风险 为了保护你的账户安全，我们中断了你的操作]和[借呗提示存在风险中断操作]的相似度为： 0.8325542
# !!!
# [False][借呗可以随时设置额度吗]和[借呗还清以后还可以再借吗]的相似度为： 0.9711081
# [False][为什么关闭不了花呗]和[如何永久关闭花呗]的相似度为： 0.95105237
# [False][关闭花呗，不用花贝支付]和[我关闭了花呗，另一个账号怎么使用]的相似度为： 0.9657359
# [True][我就想问问花呗提前还怎么还]和[怎么提前换下下个月的花呗]的相似度为： 0.8668276
# !!!
# [False][我的花呗为什么能透支]和[是我的花呗，为什么只能第一次透支***元钱]的相似度为： 0.96714395
# [False][我在花呗的优惠券退了]和[借呗有优惠券的吗]的相似度为： 0.96493316
# [False][为什么我得花呗没有分期还款项目]和[花呗没用那么多为什么要还款更多]的相似度为： 0.9170453
# [False][花呗不用的话用还嘛]和[信用住可以用花呗不]的相似度为： 0.9606381
# [False][怎么取消花呗邀请朋友帮我还]和[我想关花呗怎么办]的相似度为： 0.9159811
# [False][为什么花呗额度降了***千]和[为什么我花呗额度只有七百]的相似度为： 0.9282826
# [False][因为另外一个手机号使用我同学的，所以想把另外一个账号下面的钱，花呗什么的转到我这个账户上]和[怎么转换花呗到另一个帐号]的相似度为： 0.846225
# [False][我的花呗是什么情况]和[我花呗里的***账单是什么意思时候用的]的相似度为： 0.9140661
# [False][借呗还款分六期还款。只要把钱存到余额宝自动扣款吗]和[余额宝超额，借呗还能自动扣款吗]的相似度为： 0.89939404
# [True][花呗无法线下付款]和[我的花呗干嘛不可以线下支付]的相似度为： 0.8131809
# !!!
# [False][双***花呗有临时额度不]和[花呗怎样提临时额度]的相似度为： 0.9417207
# [False][现在借呗还款余额有限额吗]和[余额还蚂蚁借呗额度限制]的相似度为： 0.8705166
# [False][刚申请了花呗，怎么还是收不了钱]和[信用卡花呗怎么收不了款]的相似度为： 0.91600055
# [False][蚂蚁借呗是每个月还一点，还是***个月过后一起还]和[蚂蚁借呗，借了***笔，一笔全部还完，这个月还要再还另一笔么]的相似度为： 0.9624694
# [False][为什么我看不到我的支我的花呗账单儿我]和[因为支付宝账单记录根本就没有花呗使用]的相似度为： 0.91888046
# [True][我没我有没有开通这个，花呗]和[开通这个了就开通了花呗吗]的相似度为： 0.80780077
# !!!
# [False][怎么报名参加花呗免单活动]和[就是双十一的免单活动，怎么去报名获得钥匙，然后可以获得双十一花呗的免单]的相似度为： 0.90907884
# [False][花呗晚两天会不会影响芝麻分]和[花呗分期后会影响芝麻信用吗]的相似度为： 0.9468106
# [False][我想查询下我的花呗借用了多少]和[我就是想查查我到底买什么东西用了花呗]的相似度为： 0.88663423
# [False][蚂蚁借呗什么时候可以分期***期的]和[蚂蚁借呗分期为什么没有***期了]的相似度为： 0.9999993
# [True][花呗出现尽情花呗是什麽意思]和[尽情花呗有什么限制]的相似度为： 0.94149303
# !!!
# [True][花呗分期中额度还能用吗]和[花呗分期后 还可以继续使用吗]的相似度为： 0.9999936
# !!!
# [False][蚂蚁花呗的学历信息能修改吗]和[蚂蚁借呗的个人信息怎么修改]的相似度为： 0.99999994
# [True][支付宝换手里号会对蚂蚁借呗有影响吗]和[手机变更后，支付宝借呗有影响吗]的相似度为： 0.9999974
# !!!
# [False][这个月的花呗可不可以下下个月再还]和[花呗可以到月底还吗]的相似度为： 0.7664759
# [False][我是花呗的额度]和[花呗里的额度是什么意思]的相似度为： 0.95103145
# [True][我在淘宝买东西，钱已经用花呗付过了，可是淘宝显示没有付款]和[为什么花呗付款了，淘宝还是显示未付款]的相似度为： 0.9629517
# !!!
# [True][我要取消蚂蚁借呗的放款]和[蚂蚁借呗转银行卡怎么取消]的相似度为： 0.8384224
# !!!
# [False][蚂蚁借呗封了嘛]和[蚂蚁借呗开了为啥给我关了]的相似度为： 0.99995303
# [False][我在淘宝用花呗买了东西，提前还款了，但是东西不满意退回去了，退回的钱在哪]和[用花呗买的东西 后来退了 但是在退货之前花呗已经还完了 退回来的钱在哪里]的相似度为： 0.9530828
# [False][如何更改花呗临时额度]和[花呗额度调整错误以后怎么更改]的相似度为： 0.9339284
# [True][怎么不能用花呗分期]和[我的花呗为什么不可分期了]的相似度为： 0.96620375
# !!!
# [True][花呗账单到了可以分期吗]和[我的花呗到时候能分期还款吗]的相似度为： 0.8713852
# !!!
# [False][花呗首单立减两元]和[花呗立减怎么回事]的相似度为： 0.81350136
# [True][还款后能否继续使用花呗]和[逾期后还清还能用花呗吗]的相似度为： 1.0
# !!!
# [False][花呗利息是多少]和[花呗是用一次扣一块钱]的相似度为： 0.7409418
# [False][为什么我的借呗要分***期还了]和[为什么我老公没有蚂蚁借呗]的相似度为： 0.9445485
# [False][花呗怎么取消分期]和[我要怎样取消花呗]的相似度为： 0.8798171
# [True][收钱码可以刷信用卡花呗吗]和[申请的收款码可以用信用卡或者是花呗付款么]的相似度为： 0.99998474
# !!!
# [False][花呗额度可以提高芝麻信用吗]和[怎样做可以提升花呗额度]的相似度为： 0.99999344
# [True][口碑商家可以用信用卡或花呗吗]和[口碑外卖可以用花呗吗]的相似度为： 0.9526913
# !!!
# [False][收钱码花呗一次可以支付多少钱]和[蚂蚁花呗的收钱码和支付宝的收钱码是一样的吗]的相似度为： 0.8954632
# [False][借呗，可以同时借多少笔]和[刚开通借呗可借多少元]的相似度为： 0.9999972
# [True][花呗逾期之后能再次使用么]和[花呗逾期后还款什么条件可以继续使用]的相似度为： 0.99998593
# !!!
# [False][花呗里还款还的点确定收货吗]和[花呗在未确定收货会自动确定吗]的相似度为： 0.92136335
# [True][花呗可以不绑定银行卡还钱吗]和[花呗一定要邦定银行卡吗]的相似度为： 0.9999936
# !!!
# [True][啥时候恢复我的借呗]和[什么时候给我解封借呗]的相似度为： 0.99999696
# !!!
# [True][借呗还款问题]和[怎样还蚂蚁借呗]的相似度为： 0.96616757
# !!!
# [True][我的两个花呗订单总额与我应还款总额对不上]和[花呗上显示的还款额度跟我实际用的不一样]的相似度为： 0.9571651
# !!!
# [False][借呗还款怎么显示界面]和[借呗自动还款失败后怎么还款]的相似度为： 0.9633416
# [False][蚂蚁借呗那里不是会在余额宝扣钱的吗怎么没扣]和[***点 没有扣借呗的钱是怎么回事]的相似度为： 0.9413245
# [True][我的花呗为啥提示的是别人的账号]和[花呗的账号不是我的]的相似度为： 0.8864143
# !!!
# [False][我花呗分期不够怎么办]和[***的额度不够花呗分期吗]的相似度为： 0.84142995
# [False][花呗开通后不用有年费之类的吗]和[花呗我这个月使用，下几个月不用，会有费用吗]的相似度为： 0.88267505
# [False][蚂蚁借呗可以从少到多这样还吗]和[蚂蚁借呗本月借本月还吗]的相似度为： 0.91105336
# [False][借呗晚几天还可以吗]和[借呗一月一还吗]的相似度为： 0.99998695
# [True][今天蚂蚁花呗如何还款]和[使用蚂蚁花呗付款，怎样还款]的相似度为： 0.99998397
# !!!
# [False][网商货和借呗区别]和[借呗和网商，那有什么不一样]的相似度为： 0.9660992
# [False][蚂蚁借呗关闭需要多久才能恢复]和[蚂蚁借呗多长时间可以恢复]的相似度为： 0.96065277
# [False][怎么在电脑上开通花呗]和[花呗怎么绑定手机？原来开通花呗是绑定电脑帐号的]的相似度为： 0.9802138
# [True][关闭花呗收钱]和[关闭花呗和信用卡收款码]的相似度为： 0.99994123
# !!!
# [True][怎么看花呗上个月的账单]和[花呗账单在哪里看，买了些什么]的相似度为： 0.9495261
# !!!
# [False][花呗规定还三百多，我还一部分可以不算逾期吗]和[花呗也是宽限期还款的，会影响芝麻分吗]的相似度为： 0.9449071
# [False][能删去花呗借呗的纪录吗]和[蚂蚁借呗的逾期负面记录也不能删除吗]的相似度为： 0.9089413
# [False][红包和花呗分期]和[花呗红包没有领]的相似度为： 0.91591203
# [False][蚂蚁借呗关闭后如何注销蚂蚁信用分]和[不想使用了借呗，如何注销账户]的相似度为： 0.9640732
# [False][我的借呗额度好久没有提升]和[我的借呗额度什么没提升]的相似度为： 0.9999981
# [False][双***用支付宝花呗买了东西怎么没有记录了]和[怎么查询花呗借呗有不良记录]的相似度为： 0.8544723
# [True][这一笔但我是用什么支付的？（余额宝？花呗？ ）]和[是用了余额宝还是花呗付款]的相似度为： 0.9169415
# !!!
# [False][蚂蚁借呗日利息***%如何降低]和[蚂蚁借呗提前还款利息]的相似度为： 0.92912304
# [True][为什么蚂蚁借呗不可以借钱]和[我蚂蚁借呗不能使用了]的相似度为： 0.7873723
# !!!
# [False][我的花呗里面没有显示退款]和[我先用的花呗，收到货就立即支付款了，为什么花呗没有显示]的相似度为： 0.9156823
# [False][我的花呗帐已经还清了]和[能查到我是否以还清花呗的欠款]的相似度为： 0.99997807
# [True][蚂蚁花呗分期可以提前还下月账单吗]和[花呗分期还款提前结清]的相似度为： 0.9244512
# !!!
# [False][怎么花呗支付不了手机充话费了]和[我的花呗支付怎么没有啦]的相似度为： 0.87678957
# [False][借呗到还款时间为什么没有扣钱]和[蚂蚁借呗还钱什么时候扣款]的相似度为： 0.9282999
# [False][我的花呗为什么还没解冻]和[花呗冻结了，跟我解开]的相似度为： 0.9640051
# [False][我换了号码可以开通另外一个花呗]和[多会花呗可以开通]的相似度为： 0.9801891
# [False][花呗申请分期付款后可以先还一半吗]和[花呗可以在还款日之前一半一半还吗]的相似度为： 0.9521859
# [False][我是说借呗可以分期还款吗]和[蚂蚁借呗还款是分期吗]的相似度为： 0.92956996
# [False][身份证过期会影响开通蚂蚁借呗吗]和[借呗身份证过期了 还清还能借吗]的相似度为： 0.954168
# [False][我花呗停了就不能用了]和[我的花呗还能吗]的相似度为： 0.8414577
# [False][怎么信用额度提高，开通借呗]和[我想借呗提升额度么]的相似度为： 0.96486515
# [False][借呗的还款方式，怎么设置信息后，本金]和[花呗逾期了，还了以后借呗还能用吗]的相似度为： 0.9455713
# [False][花呗的还款日是哪一天]和[今天花呗最低还款后其余的什么时候还]的相似度为： 0.8906475
# [True][我花呗忘记还款了！逾期几十块钱！这个逾期记录什么时候能清除]和[花呗逾期了的负面记录怎么删除]的相似度为： 0.9686841
# !!!
# [False][花呗挖奖得到的奖品放在哪里]和[花呗免息的活动在哪里]的相似度为： 0.92196953
# [True][花呗账单怎么不对？怎么查]和[花呗怎么查以出现账单]的相似度为： 0.9999918
# !!!
# [False][花呗已经手动还款还会自动扣钱么]和[怎么把花呗设置成自动还款]的相似度为： 0.9129813
# [True][借呗最多借几比钱]和[借呗最多可借几笔]的相似度为： 1.0
# !!!
# [False][芝麻信用分要多少分才能重新开通花呗]和[芝麻信用多少分恢复花呗]的相似度为： 0.99998134
# [True][什么条件可以开通借呗]和[达到什么条件开通借呗]的相似度为： 0.99999994
# !!!
# [True][花呗账单被删除怎样找回记录]和[花呗每月账单删除]的相似度为： 0.96068496
# !!!
# [False][借呗借***个月到期一次还完还是分期]和[借呗还款不是到期还吗]的相似度为： 0.913195
# [False][支付宝可以登录，但和花呗不是同一账号]和[花呗账号和支付宝账号不是同一个名称咋办]的相似度为： 0.9132677
# [True][花呗什么时候可以提现现金]和[花呗要多长时间可以提款]的相似度为： 0.91878545
# !!!
# [False][我够了分期还花呗的资格吗]和[花呗分期之后还能再分期吗]的相似度为： 0.9283001
# [True][花呗每月九号早上扣款还是晚上]和[花呗自动还款都是几点自动扣]的相似度为： 0.9050685
# !!!
# [False][蚂蚁借呗重开]和[为什么蚂蚁借呗会关掉]的相似度为： 0.9162576
# [False][借呗提额能高点吗]和[蚂蚁借呗快速提额度]的相似度为： 0.9640042
# [True][我有借呗但是借呗里没钱]和[我开通借呗，但是目前还没有钱可以借怎么办]的相似度为： 0.9040881
# !!!
# [True][为什么我的花呗不可用了]和[我的蚂蚁花呗为何用不了]的相似度为： 0.9662074
# !!!
# [False][我的花呗这期还款是还的哪些款]和[我这个花呗多少期的]的相似度为： 0.8413436
# [False][花呗剩余提现额度是怎么回事]和[花呗免费提现额度是怎么回事]的相似度为： 1.0
# [True][怎么不能用花呗额度付款]和[花呗***为什么用不了]的相似度为： 0.7662147
# !!!
# [True][怎么能降低借呗利息]和[能把借呗的利息降低吗]的相似度为： 0.8993734
# !!!
# [True][我有个借呗不小心逾期了，会不会对我个人信用有影响]和[蚂蚁借呗逾期一天会影响信用度吗]的相似度为： 0.91358566
# !!!
# [True][这个月花呗选分期付款 下个月能取消吗]和[取消花呗分期可以嘛]的相似度为： 0.9661001
# !!!
# [False][花呗邀请朋友还款怎么关掉]和[怎么取消花呗帮忙还钱的邀请]的相似度为： 0.8598116
# [False][把之前的花呗关闭，另一个账户可以开通吗]和[怎么把花呗从一个账户转移到另一个账户]的相似度为： 0.94488037
# [True][***月***日借花呗，什么时候还]和[我今天用花呗什么时候还款]的相似度为： 0.941277
# !!!
# [False][积分可以兑花呗分期手续费吗]和[花呗分期免手续费，要怎么用]的相似度为： 0.95210576
# [False][花呗联系人认证后不通过]和[花呗不通过，没实名]的相似度为： 0.8944932
# [False][花呗扫码不行是怎么回事]和[我的花呗怎么扫码沒可以支付]的相似度为： 0.96622586
# [False][花呗可以到***号当天还款吗]和[花呗当天几点还款]的相似度为： 0.9187121
# [False][借呗上传的身份证照片在哪里查看]和[上传身份证后借呗不能用了]的相似度为： 0.87684935
# [False][蚂蚁借呗 怎么变成网商贷]和[怎么才能把借呗改成网商贷]的相似度为： 0.9412091
# [False][我花呗已经还的钱上个月已经还清了]和[我的花呗之前显示还清了为什么现在还要还]的相似度为： 0.9685552
# [False][小商店可以用花呗吗]和[花呗可以在哪些门店用]的相似度为： 0.9606161
# [False][我花呗还有蚂蚁借呗都已经还清了，为什么还用不了蚂蚁借呗]和[我想知道我的花呗，为什么还不是排不上着，还是五百，这都两个月了]的相似度为： 0.9299709
# [False][银行卡绑定支付宝，用了借呗，银行卡手机号修改了，那会对支付宝借呗有影响么]和[我的银行卡手机号已经改好了，为什么借呗还是原来的手机]的相似度为： 0.978781
# [True][花呗最低应还款是什么]和[我的花呗还款最低]的相似度为： 0.9509885
# !!!
# [False][我是用花呗付的，订单，但是这个订单我有退货的东西，他为什么还要我还款]和[花呗上的钱我已经还了，而且我***月还没有买过东西，为什么还要还款]的相似度为： 0.9573266
# [False][花呗全民摇一摇临时额度是真的吗]和[花呗额度全民临时摇一摇额度是不是真的]的相似度为： 0.9029895
# [True][我的借呗如何变为网商贷]和[怎样从借呗升级网商贷]的相似度为： 0.91109025
# !!!
# [False][为什么我的账户没有借呗]和[为什么我的借呗突然没有了]的相似度为： 0.9640282
# [True][花呗怎麼登不进]和[登录不上去花呗]的相似度为： 0.9192537
# !!!
# [False][花呗是没关闭吗]和[支付顺序里也没有花呗]的相似度为： 0.96616
# [False][网商贷关闭后还可以用借呗吗]和[关闭借呗，能不能使用网商贷]的相似度为： 0.99999994
# [False][我的蚂蚁花呗]和[我的花呗怎么代不了款]的相似度为： 0.9999494
# [True][邮政储蓄卡支持借呗吗]和[邮政储蓄银行可以还借呗吗]的相似度为： 0.7828814
# !!!
# [False][我想把花呗的款还上]和[我想了解一下花呗是怎样还款]的相似度为： 0.9527129
# [False][蚂蚁花呗不开通]和[申请开通花呗通道]的相似度为： 0.9606288
# [True][怎么取消蚂蚁借呗申请]和[取消蚂蚁借呗功能]的相似度为： 0.8595396
# !!!
# [False][为啥换个手机没有花呗了]和[花呗换不了新手机号码吗]的相似度为： 0.7846047
# [False][用花呗付款可否享受***各种优惠]和[使用花呗付款 可以享受津贴优惠和店铺优惠吗]的相似度为： 0.7940159
# [False][花呗因为某些原因不能主动还款，可以自动扣款吗]和[花呗，我设置自动还款成功了吗]的相似度为： 0.89324594
# [False][我借呗到银行卡还本到帐，能改到余额吗]和[之前借呗都是余额宝还款，现想修改为银行卡，该如何修改]的相似度为： 0.96369594
# [True][花呗一次性怀款]和[花呗一次性全部还款]的相似度为： 0.7734926
# !!!
# [False][我用的余额充值的摩拜单车。为什么显示用的蚂蚁花呗]和[我未设置用支付宝手机充值，为什么花呗上显示自动充值了]的相似度为： 0.9073524
# [False][花呗境外额度怎么领]和[双十一花呗临时额度怎么设置]的相似度为： 0.95909953
# [False][我的花呗有额度为什么用不了]和[我为什么花呗没有额度]的相似度为： 0.96711725
# [True][我支付宝余额有钱怎样才可以拿来还花呗]和[花呗还款通过支付宝余额]的相似度为： 0.90404904
# !!!
# [True][蚂蚁借呗额度为什么没开通]和[我没有借呗额度了麽]的相似度为： 0.9750892
# !!!
# [False][我没有开通人脸识别，你们怎么给我弄的，我现在都用不了花呗]和[我记得什么，我开通花呗我能不确认那些条款吗]的相似度为： 0.91037184
# [False][什么地方可以用到花呗的]和[跟花呗到期才还款有关系么]的相似度为： 0.96498215
# [False][蚂蚁借呗分期没有***个月了么]和[借呗现在没有***月分期了吗]的相似度为： 0.8134227
# [False][我用新号码注册了支付宝，为什么花呗是老号码的]和[花呗注册电话号码换了怎么办]的相似度为： 0.9322884
# [False][支付宝和花呗的密码怎样修改]和[我要改一下花呗的我支付宝的密码]的相似度为： 0.8415793
# [False][花呗可以用支付宝账户来还款吗]和[用花呗，需要还款吗]的相似度为： 0.8585317
# [False][我的花呗的钱是怎么被扣的]和[余额被花呗扣款]的相似度为： 0.83835846
# [True][花呗的短信服务]和[花呗短信包月]的相似度为： 0.9999965
# !!!
# [False][借呗停用多长时间可以解]和[借呗怎样停用]的相似度为： 0.9638772
# [False][我之前花呗没还完现在不知道怎么还了]和[我怎么看不到花呗未还总额]的相似度为： 0.9517878
# [False][使用花呗支付的退的运费在可以查到]和[我以为花呗是你们退的运费款]的相似度为： 0.98018616
# [False][花呗怎样充值]和[怎么用花呗充值游戏点数]的相似度为： 0.8550544
# [False][蚂蚁借呗最后一步 往手机上发验证码 手机号换了怎么办]和[为您服务。 我已经在支付宝修改了手机号，为什么蚂蚁借呗还款还是已经手机号的验证码]的相似度为： 0.94375074
# [False][蚂蚁借呗能更改定期还款日期吗]和[蚂蚁借呗 提前还款后 到还款日还需要还吗]的相似度为： 0.9346764
# [False][银行卡上扣款了，花呗没还上怎么办]和[没有银行卡如何还花呗]的相似度为： 0.92120916
# [False][摩拜单车押金使用花呗但是退了两次]和[用蚂蚁花呗支付了摩拜单车的押金]的相似度为： 0.9188432
# [False][我绑卡~怎么开通不了花呗]和[为什么我都花呗还开不了]的相似度为： 0.9592029
# [False][我选择了最低还款，剩下的按日计息，随时还款]和[我可以花呗最低还款，还了最低还款是不是这个月就好了]的相似度为： 0.95679
# [True][我用的花呗，不知咋样还款]和[用了花呗付款，要怎么还款]的相似度为： 0.9283001
# !!!
# [False][还了最低还款是不是账单就直接转入下个月]和[是延续到我下一个账单日吗？还是我把这个月剩余还了就没有了]的相似度为： 0.8121745
# [True][借呗可分***期]和[借呗能不能不要分期还]的相似度为： 0.9417046
# !!!
# [True][怎么看花呗的所有未还账单]和[花呗还款订单怎么看]的相似度为： 0.8596555
# !!!
# [False][蚂蚁花呗可以支付电费吗]和[电费不可以用花呗交吗]的相似度为： 0.8270699
# [True][我的花呗怎么受不了款了]和[为什么花呗不能收款]的相似度为： 0.9140003
# !!!
# [True][花呗用不了]和[但是进入支付的时候花呗选不了]的相似度为： 0.72829366
# !!!
# [True][余额还借呗金额限制]和[金额限制怎么还借呗]的相似度为： 0.9675307
# !!!
# [False][花唄零时额度]和[花呗的零时额度在哪]的相似度为： 0.95094645
# [False][当面付收款码用花呗收款，一次能收多少钱]和[支付宝二维码收款，使用花呗的额度多大]的相似度为： 0.95216763
# [True][花呗***三个月分期手续费多少]和[花呗三期还款利息多少]的相似度为： 0.90705836
# !!!
# [False][花呗是什么业务有什么作用]和[花呗pass有什么作用及用途]的相似度为： 0.8135089
# [False][花呗信用卡收款有限额吗]和[商家信用卡与花呗收款功能是任意开关吗]的相似度为： 0.96594214
# [False][借呗借不了]和[借呗不能分一年还吗]的相似度为： 0.8180547
# [False][蚂蚁花呗提前还款可以退回吗]和[我的花呗可以一次性还吗]的相似度为： 0.9110656
# [False][为什么我办不了借呗，和花呗]和[怎么开通不了花呗和借呗]的相似度为： 0.8911058
# [False][蚂蚁借呗到期延长]和[蚂蚁借呗可以还***期]的相似度为： 0.96066153
# [True][之前的账号花呗不用了，这个号可以开通吗]和[另一个号蚂蚁花呗已关闭，别的号可以开通吗]的相似度为： 0.94130796
# !!!
# [False][我的为什么借呗还用不了]和[为什么我的借呗还款后没法使用]的相似度为： 0.99998856
# [False][为什么好多店铺不能用花呗]和[我了店铺怎么不能用花呗]的相似度为： 0.91609454
# [True][***月***号我用自己的银行卡付款的，为什么花呗出了账单]和[我晕死了，明明银行卡付款了，为什么显示花呗消费了]的相似度为： 0.93406993
# !!!
# [False][我花呗兑换优惠券在哪]和[我的花呗分期免息券在哪]的相似度为： 0.8555082
# [False][这个可以蚂蚁花呗付款吗]和[可以用花呗向别人付款吗]的相似度为： 0.8553685
# [False][我想用这个号开通花呗]和[我小号花呗关闭了，这个号开通不了]的相似度为： 0.980187
# [False][花呗的分期，能一次性还清吗]和[花呗分期怎么提前还款？减免手续费吗]的相似度为： 0.90372956
# [False][已经还完花呗了为什么不能使用]和[为什麼不能用花呗]的相似度为： 0.9999411
# [False][花呗的安全验证怎么通过]和[花呗安全组件验证]的相似度为： 0.92826915
# [False][借呗上一个版本是有分期***个月，***个月，怎么现在只有***个月分期限了]和[蚂蚁借呗怎么没有***期分期关了]的相似度为： 0.7371592
# [False][为什么我还了借呗还一直给我发信息]和[为什么借呗发验证码到旧号码]的相似度为： 0.9758302
# [False][借呗钱用完了，还可以提升吗]和[不用蚂蚁借呗可以吗]的相似度为： 0.8949909
# [False][蚂蚁花呗可以还信用卡不]和[信用卡还花呗怎么还]的相似度为： 0.95808816
# [True][什么时候才能再开通花呗]和[我什么时候使用花呗的]的相似度为： 0.9801917
# !!!
# [False][淘宝绑定不了花呗]和[花贝怎么绑定不了淘宝]的相似度为： 0.85186136
# [False][花呗的订单删除了，为什么就没有的]和[为什么我用花呗的钱，都没有用那么多]的相似度为： 0.949538
# [False][蚂蚁借呗为什么额度自动降低了]和[我的借呗为什么额度降低了不恢复]的相似度为： 0.9999991
# [False][商家花呗码总审核不通过]和[花呗收款审核不通过]的相似度为： 0.94171286
# [False][花呗零时额度失效]和[我有零时借呗 或花呗额度吗]的相似度为： 0.92944884
# [True][花呗冻结了多久可能恢复]和[花呗被冻结了什么时候才能使用了]的相似度为： 0.81326133
# !!!
# [False][花呗在额度内付款有限制金额吗]和[收取花呗和信用卡 有金额限制吗]的相似度为： 0.89618087
# [False][我已经退款了这个就不能消的吗]和[我的账单显示已经退款成功在花呗上]的相似度为： 0.9090916
# [True][***花呗有临时额度么]和[双***花呗会有臨時額度嗎]的相似度为： 0.944734
# !!!
# [True][求求你们了，我现在需要花呗提额度，要买东西]和[如何提高花呗的额度]的相似度为： 0.9055175
# !!!
# [False][借呗还款清后，怎么借不了款]和[借呗逾期三天 还钱后不能借了]的相似度为： 0.9606112
# [True][已经退款花呗了。要还的钱依然没有少]和[我的交易已经退款了，可是花呗里面欠的并没有少]的相似度为： 0.9468327
# !!!
# [True][我的支付宝一直更新都没有，花呗]和[我的怎么没有花呗]的相似度为： 0.91159606
# !!!
# [False][蚂蚁借呗里的钱不够用怎么办]和[账户里的钱不够还蚂蚁借呗，会怎样]的相似度为： 0.9117727
# [True][我想提前把***月的花呗结清]和[提前还花呗可以一次结清吗]的相似度为： 0.8714221
# !!!
# [False][是借呗，不是信用卡]和[借呗和信用卡一样吗]的相似度为： 0.9163969
# [False][我那花呗，两个了怎么没加]和[花呗没个月都还清了，为什么额度没有提升]的相似度为： 0.9295672
# [False][花呗使用额度为负数，会有影响吗]和[花呗额度负数，会影响订单不]的相似度为： 0.9657091
# [False][怎么自定义花呗额度]和[我的花呗额度怎么还不提额度]的相似度为： 0.97819984
# [True][更改花呗之前绑定的手机号]和[我的花呗还是这个手机号怎么休改]的相似度为： 0.89500356
# !!!
# [False][我网商贷只有***]和[我不要网商贷]的相似度为： 0.9191797
# [False][可是我的借呗有额度的]和[我的借呗什么时候可以在使用]的相似度为： 0.8184141
# [False][借呗借款第一次短信提醒是多久]和[借呗怎么改短信提醒]的相似度为： 0.9446759
# [False][我的花呗是分了多少期]和[花呗可以分多少期]的相似度为： 0.8134098
# [False][我昨天银行卡没有及时到账 导致蚂蚁花呗没有及时还款]和[我支付宝余额年限了 没有银行卡 怎么还花呗]的相似度为： 0.9192318
# [False][为什么我没开通淘宝花呗，有额度***]和[为什么这么多年了我就是没有花呗]的相似度为： 0.85875344
# [False][蚂蚁借呗有钱就能还款吗]和[蚂蚁借呗还款日是几号？最迟几号还款]的相似度为： 0.9036038
# [False][借呗的每期是怎么还]和[我借呗怎么不是***期的吗]的相似度为： 0.9520668
# [False][怎么能不用网商贷用借呗]和[网商贷跟借呗一样吗]的相似度为： 0.89936364
# [False][这个可以蚂蚁花呗收款吗]和[首款码可以花呗收款吗]的相似度为： 0.99999785
# [False][是的，我有钱用你花呗的钱干嘛吊你]和[这样的话，万一我的淘宝被盗岂不是可以随便用我的花呗]的相似度为： 0.940594
# [False][花呗分期是收钱的了]和[花呗多收我一笔钱]的相似度为： 0.9606576
# [False][我刚还了一笔花呗，但我不确定是从哪个账户还的]和[我每个月花呗都是自动还款的。可是这次我已经还了一部分钱了。剩下未还的自动还款是还全额还是我剩下没有还清的]的相似度为： 0.9058027
# [False][十月份的花呗]和[我的花呗咋换钱]的相似度为： 0.9656846
# [False][双十二还会给出花呗临时额度吗]和[花呗的临时额度使用之后能分期还款吗]的相似度为： 0.9325756
# [False][花呗，分期付多少钱]和[支付宝花呗可以分期]的相似度为： 0.9140081
# [False][花呗可以密付款吗]和[密付会用花呗嘛]的相似度为： 0.78295314
# [False][花呗最低还款算不算预期]和[花呗的最低还款是总额度的百分之几]的相似度为： 0.99997854
# [False][我没有绑定银行卡怎么还花呗借款]和[我早上还款***元银行卡出账了但是花呗欠额没减少]的相似度为： 0.8685776
# [True][我线下支付的花呗]和[花呗可以线下支付吗]的相似度为： 0.7736332
# !!!
# [False][我的花呗额度是一万，为什么不能使用]和[花呗无法使用是为什么]的相似度为： 0.74086976
# [True][怎么看我的借呗还款纪录]和[借呗怎么查还款纪录]的相似度为： 0.963994
# !!!
# [False][为什么会蚂蚁借呗只能借***个月了]和[蚂蚁借呗之前可以借十二个月，为什么现在只能借六个月了]的相似度为： 0.9169947
# [False][我的花呗线下用不了了]和[我记得之前的花呗是有***万的额度]的相似度为： 0.8755848
# [False][支付宝商家收钱码不开通信用卡、花呗收钱功能，只是普通的支付宝收钱要不要扣手续费]和[商家用花呗收钱扣手续费吗]的相似度为： 0.95207095
# [True][有两个支付宝账户，第二个不能开通借呗，花呗]和[为什么开通不了借呗，花呗]的相似度为： 0.96314025
# !!!
# [False][为啥我的借呗没有啦]和[我的怎么没有蚂蚁借呗窗口]的相似度为： 0.91604716
# [False][怎么改为手动还借呗款]和[蚂蚁借呗，没有绑卡怎么还款]的相似度为： 0.965758
# [False][关闭花呗为什么还能用花呗支付]和[我关闭了花呗为啥付不了款]的相似度为： 0.8555417
# [False][花呗不欠钱了那我退款了钱到哪里去了]和[花呗分期付款退款退到哪]的相似度为： 0.9829711
# [False][我花呗分***期，现在怎么成***期了]和[花呗花了***分***期一期付多少]的相似度为： 0.8888163
# [False][花呗怎么在淘宝上买东西]和[如何在淘宝使用花呗]的相似度为： 0.941476
# [False][我的花呗额度很久没提了]和[假如我使用花呗的时候没有银行卡可以吗]的相似度为： 0.9071486
# [False][我的花呗什么时候可以再次使用]和[我什么时候花呗能从新开通]的相似度为： 0.8982756
# [False][怎么样把借呗取消]和[饿了么授权怎么取消]的相似度为： 0.7662089
# [False][借呗短期借款有什么用]和[借呗短期开放的标准是什么]的相似度为： 0.99999076
# [False][使用的借呗之后，可以出国吗，因为我的工作在国外，我需要在国外还款]和[借呗这个月分期还款了，还了的钱还可以再次取出用吗]的相似度为： 0.9430157
# [False][还要多久能开通花呗]和[花呗要多久才会重新开通]的相似度为： 0.9605887
# [False][怎样设置花呗访问手机通讯录]和[花呗读取不了手机通讯录权限]的相似度为： 0.9260262
# [False][花呗的学历填错了，可不可以改]和[花呗学历填错了怎样修改]的相似度为： 0.9670762
# [True][我的淘宝绑不了花呗]和[怎么花呗绑不了淘宝]的相似度为： 0.9213587
# !!!
# 1338

# %%
s1_encoded = tokenizer([p[0] for p in dev_sentence_pairs], padding=True, truncation=True, max_length=MAX_LEN,return_tensors="tf")
s1_embeddings = sentence_embedding_model.predict([s1_encoded['input_ids'],s1_encoded['token_type_ids'],s1_encoded['attention_mask']])
s2_embeddings = sentence_embedding_model.predict(tokenizer([p[1] for p in dev_sentence_pairs], padding=True, truncation=True, max_length=MAX_LEN,return_tensors="tf").values())
dev_score = tf.linalg.diag_part(tf.linalg.matmul(s1_embeddings,tf.transpose(s2_embeddings)))

# %%
tf.reduce_sum(tf.cast(tf.equal(dev_score>0.5,dev_labels),dtype=tf.int16))
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=2217>

# %%
# Out:
# <tf.Tensor: shape=(4316,), dtype=bool, numpy=array([False, False,  True, ..., False, False,  True])>

# %%
np.matmul(s1_embeddings[1], s2_embeddings[1])

# %%
s1,s2 = dev_sentence_pairs[1]

# %%
s1

# %%
s1_embedding = sentence_embedding_model.predict(tokenizer([s1,'万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃'],return_tensors='tf',padding=True,truncation=True,max_length=MAX_LEN).values())[0]
s2_embedding = sentence_embedding_model.predict(tokenizer([s2,'万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃'],return_tensors='tf',padding=True,truncation=True,max_length=MAX_LEN).values())[0]
np.matmul(s1_embedding,s2_embedding)

# %%
s1_embedding = sentence_embedding_model.predict(tokenizer(s1,return_tensors='tf',padding=True,truncation=True,max_length=MAX_LEN).values())[0]
s2_embedding = sentence_embedding_model.predict(tokenizer(s2,return_tensors='tf',padding=True,truncation=True,max_length=MAX_LEN).values())[0]
np.matmul(s1_embedding,s2_embedding)

# %%
s1_embedding = sentence_embedding_model(tokenizer([s1,'万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃'],return_tensors='tf',padding=True,truncation=True,max_length=MAX_LEN))[0]
s2_embedding = sentence_embedding_model(tokenizer([s2,'万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃'],return_tensors='tf',padding=True,truncation=True,max_length=MAX_LEN))[0]
np.matmul(s1_embedding,s2_embedding)

# %%
s1_embedding = sentence_embedding_model(tokenizer(s1,return_tensors='tf',padding=True,truncation=True,max_length=MAX_LEN),training=False)[0]
s2_embedding = sentence_embedding_model(tokenizer(s2,return_tensors='tf',padding=True,truncation=True,max_length=MAX_LEN),training=False)[0]
np.matmul(s1_embedding,s2_embedding)

# %%
s0_embedding = model(tokenizer(s1,return_tensors='tf',padding=True,truncation=True,max_length=MAX_LEN),training=False)[0]
s1_embedding = model.predict(tokenizer(s1,return_tensors='tf',padding=True,truncation=True,max_length=MAX_LEN).values())[0]
s1_embedding - s0_embedding.numpy()

# %%
tokenizer([p[0] for p in dev_sentence_pairs[:5]],padding=True,truncation=True,max_length=50)

# %%
s1_short = model(tokenizer(s1,return_tensors='tf',padding=True,truncation=True,max_length=MAX_LEN))[0]

# %%
s1_long = model(tokenizer([s1,'大家好我们都是中国人中国人就是厉害每天工作20个小时哈哈哈'],return_tensors='tf',padding=True,truncation=True,max_length=MAX_LEN))[0]

# %%
tokenizer(s1,return_tensors='tf',padding=True,truncation=True,max_length=MAX_LEN)

# %%
e1 = sentence_embedding_model(tokenizer([s1,'万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃'],return_tensors='tf',padding=True,truncation=True,max_length=MAX_LEN))[0]
s1e = tokenizer([s1,'万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃万求将集唉就产就吃'], padding=True, truncation=True, max_length=MAX_LEN,return_tensors="tf")
e2 = sentence_embedding_model.predict([s1e['input_ids'],s1e['token_type_ids'],s1e['attention_mask']])

# %%
e2[0]
